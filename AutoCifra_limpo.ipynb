# %% [markdown]
# <a href="https://colab.research.google.com/github/jessica-aaao/AutoCifra/blob/main/AutoCifra_limpo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
# !python3 -m pip install -q -U "yt-dlp[default]"
# !pip install -q -U openai-whisper
# !pip install -q -U demucs
# !pip install -q -U pychord
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 56.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 45.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 38.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 34.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 44.6 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 8.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.7/249.7 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 7.5 MB/s eta 0:00:00
#   Building wheel for demucs (setup.py) ... done
#   Building wheel for julius (setup.py) ... done
#   Building wheel for dora-search (pyproject.toml) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for treetable (setup.py) ... done

# %%
import requests
import json
import pandas as pd
import os
import re
import unicodedata
from difflib import SequenceMatcher
from pychord import Chord
from collections import Counter

# %%
from google.colab import drive
from IPython.display import display
from bs4 import BeautifulSoup

# %%
# !git clone  https://github.com/mikezzb/lyrics-sync.git
# !git clone https://github.com/filipecalegario/ISMIR2019-Large-Vocabulary-Chord-Recognition.git
# Out:
# Cloning into 'lyrics-sync'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 26 (delta 1), reused 2 (delta 0), pack-reused 10 (from 1)
# Receiving objects: 100% (26/26), 18.88 MiB | 16.31 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Cloning into 'ISMIR2019-Large-Vocabulary-Chord-Recognition'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 152 (delta 51), reused 135 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 25.74 MiB | 16.37 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Common

# %%
class SongUrls:
    def __init__(self, name, audio, lyrics, chords):
        self.name = name
        self.audio = audio
        self.lyrics = lyrics
        self.chords = chords

    def get_name(self):
        return self.name

    def get_audio_url(self):
        return self.audio

    def get_lyrics_url(self):
        return self.lyrics

    def get_chords_url(self):
        return self.chords

# %%
def get_urls():
    """
    Carrega o arquivo CSV com as infformações das músicas.
    """
    file_path = '/content/drive/My Drive/TCC/CodeData/songs.csv'
    songs = pd.read_csv(file_path)

    return songs

# %%
def get_songs_from_csv():
    """
    Obtém as músicas, letras e cifras, além do nome da música, a partir do arquivo CSV.
    """
    songs = get_urls()

    song_urls = []

    for index, row in songs.iterrows():
        song_name = slugify(row['Song Name'])
        audio_url = row['Audio URL']
        lyrics_url = row['Lyrics URL']
        chords_url = row['Chords URL']

        song_urls.append(SongUrls(song_name, audio_url, lyrics_url, chords_url))

    return song_urls

# %%
def slugify(raw_song_name):
    """
    Converte o nome da música para um formato que pode ser usado como nome de arquivo.
    """
    song_name = raw_song_name.lower()

    song_name = unicodedata.normalize('NFKD', song_name)
    song_name = song_name.encode('ascii', 'ignore').decode('ascii')

    song_name = re.sub(r'[^a-z0-9]+', '_', song_name)

    song_name = song_name.strip('_')

    return song_name

# %%
def save_to_file(data, folder_path, song_name):
    """
    Salva os dados em um arquivo de texto.
    """
    path = f"{folder_path}/{song_name}.txt"

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    with open(path, 'w') as file:
        file.write(data)

    return path

# %% [markdown]
# # Sound

# %%
def extract_sound_recording(youtube_url, song_name):
    """
    Extrai o áudio da música a partir do vídeo do YouTube.
    """
    print(f'Extracting audio from {youtube_url}...\n\n')

    cookies_path = '/content/cookies.txt'
    output_path = f"/content/audios/{song_name}.wav"

    # !yt-dlp {youtube_url} --audio-format "wav" --cookies {cookies_path} -x -o {output_path}  -q

    return output_path

# %% [markdown]
# # Chords

# %%
def extract_chords_from(song_paths, song_names):
    """
    Extrai a cifra, com o timestamp, a partir da música
    """

    output_folder = "/content/chords"
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    output_paths = []

    # %cd ISMIR2019-Large-Vocabulary-Chord-Recognition
    # !pip install -q -r requirements.txt

    for song_path, song_name in zip(song_paths, song_names):
        output_path = f"{output_folder}/{song_name}.lab"
        # !python chord_recognition.py {song_path} {output_path}

        output_paths.append(output_path)

    # %cd ..

    return output_paths

# %% [markdown]
# # Lyrics

# %% [markdown]
# ## Lyrics Extraction from Webpage

# %%
def extract_lyrics_from_html(html):
    """
    Extrai a letra da página HTML fornecida
    """

    print(f'Fetching lyrics...!\n\n')

    lyricsTag = html.find('div', class_='lyric-original')
    lyrics = ""

    for p in lyricsTag.find_all('p'):
        for br in p.find_all('br'):
            br.replace_with('\n')
        lyrics += p.get_text() + "\n"

    return lyrics

# %%
def get_lyrics_from_webpage(lyric_urls, song_names):
    """
    Obtém a página web e extrai a letra
    """

    lyrics_paths = []
    folder_path = "/content/lyrics"

    for lyric_url, song_name in zip(lyric_urls, song_names):
        response = requests.get(lyric_url)

        if response.status_code == 200:
            htmlContent = BeautifulSoup(response.content, 'html.parser')

            lyrics = extract_lyrics_from_html(htmlContent)
            lyrics_path = save_to_file(lyrics, folder_path, song_name)

            lyrics_paths.append(lyrics_path)
        else:
            print(f"Failed to fetch {song_name} webpage. Status code: {response.status_code}\n\n")

    return lyrics_paths

# %% [markdown]
# ## Lyrics Sync to Audio

# %%
def create_output_folder():
    """
    Cria as pastas de resultados para o lyrics-sync
    """
    output_folder = "/content/lyrics-sync/output"
    vocals_folder = output_folder + "/vocals"
    words_folder = output_folder + "/words"
    lrc_folder = output_folder + "/lrc"

    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    if not os.path.exists(vocals_folder):
        os.makedirs(vocals_folder)

    if not os.path.exists(words_folder):
        os.makedirs(words_folder)

    if not os.path.exists(lrc_folder):
        os.makedirs(lrc_folder)

# %%
def get_timestamps(audio_paths, lyrics_paths, song_names):
    """
    Obtém os timestamps das palavras da letra
    """
    # !wget -c https://repo.continuum.io/archive/Anaconda3-2024.10-1-Linux-x86_64.sh
    # !chmod +x Anaconda3-2024.10-1-Linux-x86_64.sh
    # !bash ./Anaconda3-2024.10-1-Linux-x86_64.sh -b -f -p /usr/local

    # %cd lyrics-sync/
    # !conda env update -f environment.yml
    # !source activate lsync

    from lsync import LyricsSync

    lsync = LyricsSync()

    timestamps_paths = []

    for lyrics_path, audio_path, song_name in zip(lyrics_paths, audio_paths, song_names):
        words, lrc = lsync.sync(audio_path, lyrics_path)
        words_path = f"/content/lyrics-sync/output/words/{song_name}.csv"

        timestamps_paths.append(words_path)

    return timestamps_paths
    # %cd ..

# %%
def get_synced_lyrics(lyric_urls, audio_paths, song_names):
    """
    Obtém a letra sincronizada com o áudio.
    """

    lyrics_paths = get_lyrics_from_webpage(lyric_urls, song_names)
    timestamps_paths = get_timestamps(audio_paths, lyrics_paths, song_names)

    return (lyrics_paths, timestamps_paths)

# %% [markdown]
# # Chord Sheets

# %% [markdown]
# ## Chords Parsing

# %%
def translate_chord(chord):
    """
    Simplifica os acordes resconhecidos pelo modelo, para acordes mais comuns
    nas cifras.
    """
    chord = chord.replace(":", "")
    chord = chord.replace("min", "m")
    chord = chord.replace("maj", "")
    chord = chord.replace("hdim7", "m7(b5)")
    chord = chord.replace("hdim", "m7(b5)")
    chord = chord.replace("sus4(b7)", "7sus4")

    return chord

# %%
def parse_chords(chords_path):
    """
    Percorre o arquivo .lab, simplifica e extrai os acordes em um dicionário.
    """

    chords = []
    with open(chords_path, 'r', encoding='utf-8') as file:
        for line in file:
            start, end, chord = line.strip().split('\t')
            if chord == 'N':
                continue
            chord = translate_chord(chord)
            chords.append({
                "start": float(start),
                "end": float(end),
                "chord": chord
            })

        return chords

# %% [markdown]
# ## Lyrics Parsing

# %%
def parse_lyrics(timestamped_lyrics_path, lyrics_path):
    """
    Separa as letras, com timestamps, em linhas, de acordo com o arquivo da
    letra extraída pelo web scraping.
    """
    timestamped_lyrics = pd.read_csv(timestamped_lyrics_path)
    timestamped_per_line = []

    with open(lyrics_path, 'r', encoding='utf-8') as file:
        for index, line in enumerate(file):
            line = line.strip().split()
            words_in_line = len(line)

            timestamped_words = timestamped_lyrics.iloc[:words_in_line]
            timestamped_lyrics = timestamped_lyrics.iloc[words_in_line:]

            for df_index, word_info in timestamped_words.iterrows():
                start = word_info["start"]
                end = word_info["end"]
                word = word_info["label"]

                timestamped_per_line.append({
                    "word": word,
                    "start": start,
                    "end": end,
                    "line": index
                })

    return timestamped_per_line

# %% [markdown]
# ## General

# %%
def align_chord_over_word(word_info, chord_info, line_start):
    """
    Posiciona o acorde sobre a palavra.
    """
    word = word_info["word"]
    word_start = word_info["start"]
    word_end = word_info["end"]
    chord = chord_info["chord"]
    chord_start = chord_info["chord_start"]

    word_duration = word_end - word_start
    ratio = (chord_start - word_start) / word_duration

    word_len = len(word)
    word_index = int(round(ratio * (word_len - 1)))
    word_index = max(0, min(word_index, word_len - 1))

    chord_position = line_start + word_index

    return (chord, chord_position)

# %%
def overlay_chords_on_transcribed(lyrics_per_line, chords):
    """
    Associa acordes às palavras da letra com base nos tempos de ACORDES.
    """
    result = []
    previous_end = None

    for word_info in lyrics_per_line:
        start = word_info["start"]
        end = word_info["end"]
        word = word_info["word"]
        line_number = word_info["line"]

        associated_chords = []

        if start is not None and end is not None:
            for i in range(len(chords)):
                chord_infos = chords[0]
                chord_info_start = chord_infos["start"]
                chord_info_end = chord_infos["end"]
                chord_info_name = chord_infos["chord"]

                if chord_info_start > end: # Próxima palavra
                    break
                elif start <= chord_info_start <= end: # Dentro da palavra
                    chord_name = chord_info_name
                    chord_start = chord_info_start

                    associated_chords.append({
                        "chord": chord_name,
                        "chord_start": chord_start
                    })
                elif previous_end is not None and previous_end < chord_info_start < start: # Entre palavras
                    chord_name = chord_info_name
                    chord_start = chord_info_start

                    result.append({
                        "word": " ",
                        "start": start,
                        "end": end,
                        "chords": [{
                            "chord": chord_name,
                            "chord_start": chord_start
                        }],
                        "line": line_number
                    })
                elif chord_info_end >= start: # Antes da palavra
                    chord_name = chord_info_name
                    chord_start = chord_info_start

                    result.append({
                        "word": " ",
                        "start": start,
                        "end": end,
                        "chords": [{
                            "chord": chord_name,
                            "chord_start": chord_start
                        }],
                        "line": line_number
                    })

                chords.pop(0)

        result.append({
            "word": word,
            "start": start,
            "end": end,
            "chords": associated_chords,
            "line": line_number
        })

        previous_end = end

    return result

# %%
def format_transcribed_with_chords(lyrics_with_chords):
    """
    Gera o formato de saída com acordes acima das palavras.
    """
    formatted_output = []
    chord_line = []
    lyrics_line = []

    current_line = lyrics_with_chords[0]["line"]
    line_start = 0

    for word_info in lyrics_with_chords:
        if word_info["line"] != current_line:
            current_line = word_info["line"]
            formatted_output.append("".join(chord_line))
            formatted_output.append(" ".join(lyrics_line))
            formatted_output.append("")

            chord_line = []
            lyrics_line = []
            line_start = 0

        word = word_info["word"]
        chords = word_info["chords"]
        chord_position = None

        if chords:
            for chord_info in chords:
                chord = chord_info["chord"]

                if word == " ":
                    chord_line.append(chord)
                    line_start += 1
                else:
                    chord, chord_position = align_chord_over_word(word_info, chord_info, line_start)

                    while len(chord_line) < chord_position:
                        chord_line.append(" ")

                    if chord_line and chord_line[-1] != " ":
                        chord_line.append(" ")

                    chord_line.append(chord)

            line_start += len(word)
        else:
            chord_line.extend([" "] * (len(word)+1))
            line_start += len(word)

        lyrics_line.append(word)

    # Adiciona o restante, se existir
    if chord_line or lyrics_line:
        formatted_output.append("".join(chord_line))
        formatted_output.append(" ".join(lyrics_line))

    return "\n".join(formatted_output)

# %%
def save_chords_sheet(data, song_name):
    """
    Salva a cifra com acordes em um arquivo de texto.
    """
    print(f"Saving chord sheet to {song_name}.txt...")

    folder_path = "/content/chord_sheets"
    path = f"{folder_path}/{song_name}.txt"

    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    with open(path, 'w') as file:
        file.write(data)

    print(f'Saved as {path}!')

    return path

# %%
def format_song_with_chords(timestamped_lyrics_paths, lyrics_paths, chords_paths, song_names):
    """
    Formata a letra com acordes no formato tradicional de cifras.
    """
    formatted_chords = []

    for timestamped_lyrics_path, lyrics_path, chords_path, song_name in zip(timestamped_lyrics_paths, lyrics_paths, chords_paths, song_names):
        lyrics = parse_lyrics(timestamped_lyrics_path, lyrics_path)
        chords = parse_chords(chords_path)

        lyrics_with_chords = overlay_chords_on_transcribed(lyrics, chords)

        formatted_output = format_transcribed_with_chords(lyrics_with_chords)
        chord_sheet_path = save_chords_sheet(formatted_output, song_name)

        formatted_chords.append(chord_sheet_path)

    return formatted_chords

# %% [markdown]
# ---

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Cifra Club Webscraping

# %%
def has_chords(text):
    """
    Verifica se uma linha contém acordes musicais.

    Args:
        text (str): Linha de texto a ser analisada

    Returns:
        bool: True se a linha contém acordes, False caso contrário
    """
    # Expressão regular para acordes musicais
    chords_pattern = r'\b([A-G][#b]?(m|maj|min|M|add|sus|dim|aug)?[0-9]*(\([^)]+\))?|B7|E7|A7)\b'

    # Verifica se há pelo menos um acorde na linha
    if re.search(chords_pattern, text.strip()):
        return True
    else:
        return False

# %%
# Função para remover tablaturas e seções indesejadas, reduzindo múltiplas linhas em branco seguidas
def clean_cifraclub_chords(chord_sheets):
    # Remover seções como [Tab - Intro] e Parte X de Y
    chord_sheets = re.sub(r'\[.*?\]\n?', '', chord_sheets)  # Remove [Tab - Intro], [Intro], etc.
    chord_sheets = re.sub(r'Parte \d+ de \d+\n?', '', chord_sheets)  # Remove "Parte 1 de 3", etc.

    # Dividir o texto em linhas
    lines = chord_sheets.split('\n')

    # Reduzir múltiplas linhas em branco seguidas para apenas uma
    keep_lines = []
    previous_line_is_empty = False

    for line in lines:
        if re.match(r'^[EBGDAe]\|', line):  # Verificar se a linha é uma tablatura (começa com E|, B|, G|, etc.)
            if keep_lines and keep_lines[-1].split():
                keep_lines.pop()
                previous_line_is_empty = True
        else:
            if not line.strip():  # Se a linha estiver em branco
                if keep_lines and has_chords(keep_lines[-1]):
                    keep_lines.pop()
                    previous_line_is_empty = True
                if not previous_line_is_empty:  # Se a linha anterior não estiver em branco
                    keep_lines.append(line)  # Adiciona a linha em branco
                    previous_line_is_empty = True
            else:
                if keep_lines and has_chords(keep_lines[-1]) and has_chords(line): # Se a linha anterior tiver acordes
                    keep_lines.pop()

                keep_lines.append(line)
                previous_line_is_empty = False

    # Juntar as linhas novamente
    if has_chords(keep_lines[-1]):
        keep_lines.pop()

    return '\n'.join(keep_lines)

# %%
def get_chord_sheet_from_webpage(chords_url, song_name):
    """
    Obtém a página web e extrai a cifra
    """

    response = requests.get(chords_url)

    if response.status_code == 200:
        htmlContent = BeautifulSoup(response.content, 'html.parser')

        cifra_element = htmlContent.find('pre')

        if not cifra_element:
            print("Cifra não encontrada na página.")
            return None

        chords = cifra_element.get_text()
        chords = clean_cifraclub_chords(chords)
        folder_path = "/content/chords_evaluation"
        chords_path = save_to_file(chords, folder_path, song_name)

        return chords_path
    else:
        print(f"Failed to fetch the webpage. Status code: {response.status_code}\n\n")

# %% [markdown]
# ## Evaluation

# %%
# Acordes com inversões e variações - Notação Brasileira (sem "maj")
chord_inversions = {
    'C/3': ['C/E', 'C6/E', 'Cadd9/E'],
    'D/3': ['D/F#', 'D6/F#', 'D7/F#'],
    'E/3': ['E/G#', 'E6/G#', 'Eadd9/G#'],
    'F/3': ['F/A', 'F6/A', 'F7/A'],
    'G/3': ['G/B', 'G6/B', 'G7/B', 'G4/B'],
    'A/3': ['A/C#', 'A6/C#', 'A7/C#'],
    'B/3': ['B/D#', 'B6/D#', 'B7/D#'],

    'Cm/3': ['Cm/Eb', 'Cm6/Eb', 'Cm7/Eb'],
    'Dm/3': ['Dm/F', 'Dm6/F', 'Dm7/F'],
    'Em/3': ['Em/G', 'Em6/G', 'Em7/G'],
    'Fm/3': ['Fm/Ab', 'Fm6/Ab', 'Fm7/Ab'],
    'Gm/3': ['Gm/Bb', 'Gm6/Bb', 'Gm7/Bb'],
    'Am/3': ['Am/C', 'Am6/C', 'Am7/C'],
    'Bm/3': ['Bm/D', 'Bm6/D', 'Bm7/D'],

    'C/5': ['C/G', 'C7/G', 'C6/G'],
    'D/5': ['D/A', 'D7/A', 'D6/A'],
    'E/5': ['E/B', 'E7/B', 'E6/B'],
    'F/5': ['F/C', 'F7/C', 'F6/C'],
    'G/5': ['G/D', 'G7/D', 'G6/D'],
    'A/5': ['A/E', 'A7/E', 'A6/E'],
    'B/5': ['B/F#', 'B7/F#', 'B6/F#'],

    'Cm/5': ['Cm/G', 'Cm7/G', 'Cm6/G'],
    'Dm/5': ['Dm/A', 'Dm7/A', 'Dm6/A'],
    'Em/5': ['Em/B', 'Em7/B', 'Em6/B'],
    'Fm/5': ['Fm/C', 'Fm7/C', 'Fm6/C'],
    'Gm/5': ['Gm/D', 'Gm7/D', 'Gm6/D'],
    'Am/5': ['Am/E', 'Am7/E', 'Am6/E'],
    'Bm/5': ['Bm/F#', 'Bm7/F#', 'Bm6/F#'],

    'C7/3': ['C7/E', 'C9/E'],
    'D7/3': ['D7/F#', 'D9/F#'],
    'E7/3': ['E7/G#', 'E9/G#'],
    'F7/3': ['F7/A', 'F9/A'],
    'G7/3': ['G7/B', 'G9/B'],
    'A7/3': ['A7/C#', 'A9/C#'],
    'B7/3': ['B7/D#', 'B9/D#'],

    'Cm7/3': ['Cm7/Eb', 'Cm9/Eb'],
    'Dm7/3': ['Dm7/F', 'Dm9/F'],
    'Em7/3': ['Em7/G', 'Em9/G'],
    'Fm7/3': ['Fm7/Ab', 'Fm9/Ab'],
    'Gm7/3': ['Gm7/Bb', 'Gm9/Bb'],
    'Am7/3': ['Am7/C', 'Am9/C'],
    'Bm7/3': ['Bm7/D', 'Bm9/D'],

    'C7/5': ['C7/G', 'C9/G'],
    'D7/5': ['D7/A', 'D9/A'],
    'E7/5': ['E7/B', 'E9/B'],
    'F7/5': ['F7/C', 'F9/C'],
    'G7/5': ['G7/D', 'G9/D'],
    'A7/5': ['A7/E', 'A9/E'],
    'B7/5': ['B7/F#', 'B9/F#'],

    'Cm7/5': ['Cm7/G', 'Cm9/G'],
    'Dm7/5': ['Dm7/A', 'Dm9/A'],
    'Em7/5': ['Em7/B', 'Em9/B'],
    'Fm7/5': ['Fm7/C', 'Fm9/C'],
    'Gm7/5': ['Gm7/D', 'Gm9/D'],
    'Am7/5': ['Am7/E', 'Am9/E'],
    'Bm7/5': ['Bm7/F#', 'Bm9/F#'],
}


def get_chord_equivalents(chord):
    """Returns all equivalent voicings for a chord with third in bass"""
    return chord_inversions.get(chord, chord)

# %%
def update_chords_with_inversions(generated_chord_sequence, validation_chord_sequence):
    """
    Updates the chords in the generated sequence, replacing those ending with '/3'
    by their equivalent chords (inversions with the third in the bass) found in the validation sequence.
    """
    updated_sequence = []

    # Iterate through each line of the generated sequence
    for generated_line in generated_chord_sequence:
        updated_line = []
        for chord, position in generated_line:
            if chord.endswith('/3'):  # Check if the chord ends with '/3'
                # Find the equivalent chords for the '/3' chord
                equivalents = get_chord_equivalents(chord)

                # Look for the equivalent chords in the validation sequence
                found_equivalent = False  # Flag to check if an equivalent is found
                for equivalent in equivalents:
                    # Check if any of the equivalents exist in the validation sequence
                    for validation_line in validation_chord_sequence:
                        for validation_chord, _ in validation_line:
                            if equivalent == validation_chord:
                                # If an equivalent is found, replace the chord
                                updated_line.append((equivalent, position))
                                found_equivalent = True
                                break
                    if found_equivalent:
                        break

                # If no equivalent is found in the validation sequence, keep the original chord
                if not found_equivalent:
                    updated_line.append((chord, position))
            else:
                # If it's not a '/3' chord, keep the original chord
                updated_line.append((chord, position))

        updated_sequence.append(updated_line)

    return updated_sequence

# %%
def extract_chords_with_positions(chord_sheet):
    """Extracts chords along with their positions relative to lyrics."""
    chord_pattern = re.compile(r'([A-G][#b]?(maj7?|min7?|dim|aug|sus\d?|m|M)?\d*(\/\w+)?(add\d*)?)')

    lines = chord_sheet.split('\n')
    extracted_chords = []

    absolute_index = 0

    for line in lines:
        matches = list(chord_pattern.finditer(line))

        if matches:
            extracted_chords.append([(match.group(0), match.start() + absolute_index) for match in matches])

        absolute_index += len(line) + 1

    return extracted_chords

# %%
def calculate_chords_percentage(comparison, result_unique_chords, validation_unique_chords):
    """
    Calcula a porcentagem de acordes em comum entre duas listas de acordes.
    """
    total_chords = len(result_unique_chords | validation_unique_chords)  # Total de acordes únicos na cifra result

    if total_chords == 0:
        return 0

    common_chords_count = len(comparison)

    # A porcentagem de acordes comuns em relação ao total de acordes na cifra result
    common_percentage = round((common_chords_count / total_chords) * 100, 2)

    return common_percentage

# %%
# Função para normalizar acordes (remover extensões como 7, sus4, etc.)
def simplify_chord(chord):
    if not chord:
        return None
    try:
        # Usa a biblioteca pychord para extrair a fundamental e o modo
        c = Chord(chord)

        return f"{c.root}"  # Exemplo: "Gm" para "Gm7" ou "Gsus4"
    except:
        return chord  # Se não for possível normalizar, retorna o acorde original

# %%
def compare_chord_positions(result_chords, validation_chords, margin=2):
    """
    Compara os acordes de duas cifras considerando uma margem de erro nos índices e levando em conta
    as inversões com '/3' nos acordes de result_chords. Retorna um dicionário com a quantidade de posições corretas
    (iguais e semelhantes) e a quantidade de posições incorretas (diferentes, faltantes e em excesso).
    """
    correct_positions = 0  # Quantidade de posições corretas (acordes iguais ou semelhantes)
    incorrect_positions = 0  # Quantidade de posições incorretas (diferentes, faltantes ou em excesso)

    matched_chords = set()   # Guarda acordes de result_chords que encontraram pares

    # Comparação dos acordes entre result_chords e validation_chords
    for result_list in result_chords:
        for result_chord, result_index in result_list:
            found_match = False  # Flag para indicar se houve correspondência

            for i, validation_list in enumerate(validation_chords):
                for validation_chord, validation_index in validation_list:
                    if abs(result_index - validation_index) <= margin:  # Comparação dentro da margem
                        # Se os acordes forem exatamente iguais
                        if result_chord == validation_chord:
                            correct_positions += 1
                            found_match = True
                            matched_chords.add(result_chord)
                            break
                        # Se os acordes forem equivalentes (mesma raiz) ou similaridade de acorde
                        elif simplify_chord(result_chord) == simplify_chord(validation_chord):
                            correct_positions += 1
                            found_match = True
                            matched_chords.add(result_chord)
                            break

            if not found_match:
                incorrect_positions += 1  # Contabiliza como incorreto (não encontrou correspondência)

    # Acordes faltantes e em excesso
    # Faltantes: Estão em validation_chords, mas não foram pareados com result_chords
    # Em excesso: Estão em result_chords, mas não foram pareados com validation_chords
    missing_chords = [
        (chord, idx) for validation_list in validation_chords for chord, idx in validation_list
        if chord not in matched_chords
    ]
    extra_chords = [
        (chord, idx) for result_list in result_chords for chord, idx in result_list
        if chord not in matched_chords
    ]

    # Faltantes e em excesso também são considerados como incorretos
    incorrect_positions += len(missing_chords) + len(extra_chords)

    percentage = round((correct_positions / (correct_positions + incorrect_positions)) * 100, 2)

    return {
        "posicoes_corretas": correct_positions,
        "posicoes_incorretas": incorrect_positions
    }, percentage

# %%
def calculate_percentage_comparison_from_count(count_comparison):
    """
    Calcula a porcentagem de acordes iguais e diferentes, dado o dicionário de contagens comparativas de acordes.
    """
    common_chords_count = 0
    different_chords_count = 0
    total_chords = 0

    # Calculando a quantidade de acordes iguais e diferentes
    for chord, (result_count, validation_count) in count_comparison.items():
        total_chords += 1

        if result_count == validation_count:
            common_chords_count += 1  # Acordes iguais
        else:
            different_chords_count += 1  # Acordes diferentes

    if total_chords == 0:
        return {
            "equal_percentage": 0,
            "different_percentage": 0
        }

    equal_percentage = round((common_chords_count / total_chords) * 100, 2)
    different_percentage = round((different_chords_count / total_chords) * 100, 2)

    return {
        "equal_percentage": equal_percentage,
        "different_percentage": different_percentage
    }

# %%
def sequence_diff(generated_chord_sequence, validation_chord_sequence):
    """Compares two sequences and highlights similarities and differences."""
    generated_simplified = [simplify_chord(chord) for chord in generated_chord_sequence]
    validation_simplified = [simplify_chord(chord) for chord in validation_chord_sequence]

    matcher = SequenceMatcher(None, generated_simplified, validation_simplified)

    diff_result = {
        "sequências": [],
        "substituições": [],
        "exclusões": [],
        "inserções": [],
        "porcentagem_iguais": 0,
        "porcentagem_diferentes": 0
    }

    total_sequences = 0
    equal_count = 0
    different_count = 0

    for tag, i1, i2, j1, j2 in matcher.get_opcodes():
        total_sequences += 1  # Cada operação é uma sequência

        if tag == 'equal':
            seq = generated_chord_sequence[i1:i2]
            diff_result["sequências"].append(seq)
            equal_count += 1
        elif tag == 'replace':
            seq = {
                "cifra gerada": generated_chord_sequence[i1:i2],
                "cifra validacao": validation_chord_sequence[j1:j2]
            }
            diff_result["substituições"].append(seq)
            different_count += 1
        elif tag == 'delete':
            seq = generated_chord_sequence[i1:i2]
            diff_result["exclusões"].append(seq)
            different_count += 1
        elif tag == 'insert':
            seq = validation_chord_sequence[j1:j2]
            diff_result["inserções"].append(seq)
            different_count += 1

    if total_sequences > 0:
        diff_result["porcentagem_iguais"] = round((equal_count / total_sequences) * 100, 2)
        diff_result["porcentagem_diferentes"] = round((different_count / total_sequences) * 100, 2)


    return diff_result

# %%
def calculate_chords_count_errors(result_chords, validation_chords):
    result_total_chords = len(result_chords)
    validation_total_chords = len(validation_chords)

    total = result_total_chords + validation_total_chords

    media = round((abs(result_total_chords - validation_total_chords)/total) * 100 , 2)

    return media

# %%
def compare_chords(result_path, chords_evaluation_path):
    with open(result_path, 'r', encoding='utf-8') as file:
        result_sheet = file.read()
    with open(chords_evaluation_path, 'r', encoding='utf-8') as file:
        validation_sheet = file.read()

    """Compares two chord sheets based on extracted chords."""
    result_chords = extract_chords_with_positions(result_sheet)
    validation_chords = extract_chords_with_positions(validation_sheet)

    result_chords = update_chords_with_inversions(result_chords, validation_chords)

    result_chords_flat = [chord for line in result_chords for chord, _ in line]
    validation_chords_flat = [chord for line in validation_chords for chord, _ in line]

    count_error_media = calculate_chords_count_errors(result_chords_flat, validation_chords_flat)

    result_chords_count = Counter(result_chords_flat)
    validation_chords_count = Counter(validation_chords_flat)

    result_unique_chords = set(result_chords_flat)
    validation_unique_chords = set(validation_chords_flat)

    common_chords = result_unique_chords & validation_unique_chords
    common_chords_percentage = calculate_chords_percentage(common_chords, result_unique_chords, validation_unique_chords)

    only_on_result = result_unique_chords - validation_unique_chords
    only_on_result_percentage = calculate_chords_percentage(only_on_result, result_unique_chords, validation_unique_chords)

    only_on_validation = validation_unique_chords - result_unique_chords
    only_on_validation_percentage = calculate_chords_percentage(only_on_validation, result_unique_chords, validation_unique_chords)

    positions_comparison, positions_comparison_percentage = compare_chord_positions(result_chords, validation_chords)

    count_comparison = {chord: (result_chords_count[chord], validation_chords_count.get(chord, 0)) for chord in result_unique_chords | validation_unique_chords}
    count_comparison_percentage = calculate_percentage_comparison_from_count(count_comparison)

    sequence_diff_result = sequence_diff(result_chords_flat, validation_chords_flat)

    return {
        "Diferença de Quantidade Gerada (%)": count_error_media,
        "Acordes em Comum": common_chords,
        "Acordes em Comum (%)": common_chords_percentage,
        "Só na Cifra Gerada": only_on_result,
        "Só na Cifra Gerada (%)": only_on_result_percentage,
        "Só na Cifra de Validação": only_on_validation,
        "Só na Cifra de Validação (%)": only_on_validation_percentage,
        "Acordes com Contagem": count_comparison,
        "Acordes com Contagem Igual (%)": count_comparison_percentage["equal_percentage"],
        "Posições dos Acordes": positions_comparison,
        "Posições Iguais dos Acordes (%)": positions_comparison_percentage,
        "Sequências": sequence_diff_result,
        "Sequências Iguais (%)": sequence_diff_result["porcentagem_iguais"]
    }

# %% [markdown]
# ## General Analysis

# %%
import numpy as np
from tabulate import tabulate

def calculate_general_averages(chords_data):
    """
    Calculate general averages for the analyzed chord data.
    """

    metrics = [
        "Diferença de Quantidade Gerada (%)",
        "Acordes em Comum (%)",
        "Só na Cifra Gerada (%)",
        "Só na Cifra de Validação (%)",
        "Acordes com Contagem Igual (%)",
        "Posições Iguais dos Acordes (%)",
        "Sequências Iguais (%)"
    ]

    results = {metric: [] for metric in metrics}

    for chord in chords_data:
        for metric in metrics:
            parts = metric.split(".")
            value = chord
            for part in parts:
                value = value.get(part, 0) if isinstance(value, dict) else 0
            results[metric].append(value)

    statistics = []
    for metric, values in results.items():
        statistics.append([metric, round(np.mean(values), 2), round(np.std(values), 2)])

    headers = ["Metric", "Average (%)", "Standard Deviation (%)"]
    table = tabulate(statistics, headers=headers, tablefmt="pretty")

    print(table)

# %%
from collections import Counter
from tabulate import tabulate

def analyze_exclusive_chords(chords_data):
    """
    Analyze the distribution of chords that appear exclusively in either the generated or validation sequences.

    This function calculates:
    - The most frequent chords appearing only in the generated sequences.
    - The most frequent chords appearing only in the validation sequences.
    - Patterns in exclusive chord appearances.
    """

    only_on_result_counter = Counter()
    only_on_validation_counter = Counter()

    for chord in chords_data:
        only_on_result_counter.update(chord.get("Só na Cifra Gerada", []))
        only_on_validation_counter.update(chord.get("Só na Cifra de Validação", []))

    # Find the most frequent exclusive chords
    top_result_chords = only_on_result_counter.most_common(10)  # Top 10 chords only in generated sequences
    top_validation_chords = only_on_validation_counter.most_common(10)  # Top 10 chords only in validation sequences

    # Identify chords that appear frequently in only one category
    frequently_exclusive_chords = {
        "only_on_result": [chord for chord, count in only_on_result_counter.items() if count > 5],  # Threshold > 5
        "only_on_validation": [chord for chord, count in only_on_validation_counter.items() if count > 5]
    }

    # Format the results as tables
    result_table = tabulate(top_result_chords, headers=["Chord (Generated Only)", "Frequency"], tablefmt="pretty")
    validation_table = tabulate(top_validation_chords, headers=["Chord (Validation Only)", "Frequency"], tablefmt="pretty")

    print("Acordes Mais Frequentes (Só Geradas):\n", result_table)
    print("Acordes Mais Frequentes (Só Validação):\n", validation_table)

# %%
import numpy as np
from tabulate import tabulate

def analyze_sequence_differences(chords_data):
    """
    Analyzes sequence differences across multiple analyzed chord data.

    This function calculates:
    - The average percentage of identical sequences.
    - The average percentage of different sequences.
    - The total count of substitutions, deletions, and insertions.
    - Identifies whether insertions or deletions are the dominant errors.
    """

    identical_percentages = []
    different_percentages = []
    total_substitutions = 0
    total_deletions = 0
    total_insertions = 0

    for data in chords_data:
        seq_diff = data.get("Sequências", {})

        identical_percentages.append(seq_diff.get("porcentagem_iguais", 0))
        different_percentages.append(seq_diff.get("porcentagem_diferentes", 0))

        total_substitutions += len(seq_diff.get("substituições", []))
        total_deletions += len(seq_diff.get("exclusões", []))
        total_insertions += len(seq_diff.get("inserções", []))

    # Calculate averages
    avg_identical = round(np.mean(identical_percentages), 2) if identical_percentages else 0
    avg_different = round(np.mean(different_percentages), 2) if different_percentages else 0

    # Determine the dominant error type
    dominant_error = "Inserções" if total_insertions > total_deletions else "Exclusões"

    # Format the results in a table
    table_data = [
        ["Média de Sequências Iguais (%)", avg_identical],
        ["Média de Sequências Diferentes (%)", avg_different],
        ["Total de Substituições", total_substitutions],
        ["Total de Exclusões", total_deletions],
        ["Total de Inserções", total_insertions],
        ["Tipo de Erro Dominante", dominant_error]
    ]

    print(tabulate(table_data, headers=["Metric", "Value"], tablefmt="pretty"))

# %% [markdown]
# # MAIN

# %%
songs = get_songs_from_csv()

song_names = []
song_paths = []
lyrics_urls = []
chord_sheets = []
evaluation_paths = []

for song in songs:
    song_name = song.get_name().replace(" ", "_")
    song_names.append(song_name)

    song_path = extract_sound_recording(song.get_audio_url(), song_name)
    song_paths.append(song_path)

    lyrics_urls.append(song.get_lyrics_url())

    evaluation_path = get_chord_sheet_from_webpage(song.get_chords_url(), song_name)
    evaluation_paths.append(evaluation_path)

chords_paths = extract_chords_from(song_paths, song_names)

create_output_folder()
lyrics_paths, lyrics_timestamped_paths = get_synced_lyrics(lyrics_urls, song_paths, song_names)

chord_sheets = format_song_with_chords(lyrics_timestamped_paths, lyrics_paths, chords_paths, song_names)
# Out:
# Extracting audio from https://youtu.be/kFpkyT_KPpc...
#
#
# Extracting audio from https://youtu.be/eCyMh-mZ1B0...
#
#
# Extracting audio from https://youtu.be/CugYXgJ2SFI?t=11...
#
#
# Extracting audio from https://youtu.be/VchbqjKk6wA...
#
#
# Extracting audio from https://youtu.be/KkCre5ZEbVU...
#
#
# Extracting audio from https://youtu.be/ePFQIiLI1G8...
#
#
# Extracting audio from https://youtu.be/dHEqjSdDKok...
#
#
# Extracting audio from https://youtu.be/Y59pC4FcBxM...
#
#
# Extracting audio from https://youtu.be/lnjZ2pqI6Z8...
#
#
# Extracting audio from https://youtu.be/WuenyQ4NCQE...
#
#
# Extracting audio from https://youtu.be/wqiKeSfdsrc...
#
#
# Extracting audio from https://youtu.be/g2P_OupxkB8...
#
#
# Extracting audio from https://youtu.be/25nv3865Ak0...
#
#
# Extracting audio from https://youtu.be/nVjsGKrE6E8...
#
#
# Extracting audio from https://youtu.be/Oa_RSwwpPaA...
#
#
# Extracting audio from https://youtu.be/vx2u5uUu3DE...
#
#
# Extracting audio from https://youtu.be/u9sRJ-eOHnc...
#
#
# Extracting audio from https://youtu.be/YC0BPcLea0Y...
#
#
# Extracting audio from https://youtu.be/O-fyNgHdmLI...
#
#
# Extracting audio from https://youtu.be/Zi8mrT4l6vg...
#
#
# /content/ISMIR2019-Large-Vocabulary-Chord-Recognition
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 101.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 118.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.3/48.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 5.5 MB/s eta 0:00:00
#   Building wheel for pretty_midi (setup.py) ... done
#   Building wheel for jams (setup.py) ... done
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/que_pais_e_este.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/que_pais_e_este.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/que_pais_e_este.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/que_pais_e_este.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/que_pais_e_este.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/infiel.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/infiel.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/infiel.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/infiel.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/infiel.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/tocando_em_frente.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/tocando_em_frente.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/tocando_em_frente.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/tocando_em_frente.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/tocando_em_frente.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/petrolina_juazeiro.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/petrolina_juazeiro.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/petrolina_juazeiro.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/petrolina_juazeiro.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/petrolina_juazeiro.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/naquela_mesa.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/naquela_mesa.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/naquela_mesa.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/naquela_mesa.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/naquela_mesa.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/uma_carta.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/uma_carta.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/uma_carta.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/uma_carta.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/uma_carta.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/como_vai_voce.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/como_vai_voce.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/como_vai_voce.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/como_vai_voce.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/como_vai_voce.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/evidencias.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/evidencias.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/evidencias.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/evidencias.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/evidencias.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/sozinho.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/sozinho.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/sozinho.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/sozinho.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/sozinho.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/garota_de_ipanema.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/garota_de_ipanema.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/garota_de_ipanema.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/garota_de_ipanema.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/garota_de_ipanema.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/joao_e_maria.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/joao_e_maria.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/joao_e_maria.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/joao_e_maria.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/joao_e_maria.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/aguas_de_marco.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/aguas_de_marco.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/aguas_de_marco.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/aguas_de_marco.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/aguas_de_marco.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/corcovado.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/corcovado.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/corcovado.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/corcovado.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/corcovado.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/summertime_sadness.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/summertime_sadness.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/summertime_sadness.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/summertime_sadness.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/summertime_sadness.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/beautiful_things.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/beautiful_things.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/beautiful_things.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/beautiful_things.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/beautiful_things.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/it_s_my_life.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/it_s_my_life.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/it_s_my_life.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/it_s_my_life.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/it_s_my_life.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/always_on_my_mind.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/always_on_my_mind.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/always_on_my_mind.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/always_on_my_mind.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/always_on_my_mind.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/love_me_tender.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/love_me_tender.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/love_me_tender.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/love_me_tender.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/love_me_tender.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/my_sacrifice.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/my_sacrifice.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/my_sacrifice.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/my_sacrifice.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/my_sacrifice.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s0.best on /content/audios/wherever_you_will_go_fotos.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s1.best on /content/audios/wherever_you_will_go_fotos.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s2.best on /content/audios/wherever_you_will_go_fotos.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s3.best on /content/audios/wherever_you_will_go_fotos.wav
# Inference: joint_chord_net_ismir_naive_v1.0_reweight(0.0,10.0)_s4.best on /content/audios/wherever_you_will_go_fotos.wav
# /content
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# Fetching lyrics...!
#
#
# --2025-04-04 23:12:36--  https://repo.continuum.io/archive/Anaconda3-2024.10-1-Linux-x86_64.sh
# Resolving repo.continuum.io (repo.continuum.io)... 104.18.176.84, 104.18.177.84, 2606:4700::6812:b154, ...
# Connecting to repo.continuum.io (repo.continuum.io)|104.18.176.84|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh [following]
# --2025-04-04 23:12:36--  https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1102495056 (1.0G) [application/octet-stream]
# Saving to: ‘Anaconda3-2024.10-1-Linux-x86_64.sh’
#
# Anaconda3-2024.10-1 100%[===================>]   1.03G   151MB/s    in 11s
#
# 2025-04-04 23:12:47 (97.5 MB/s) - ‘Anaconda3-2024.10-1-Linux-x86_64.sh’ saved [1102495056/1102495056]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Anaconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Anaconda3: /usr/local
# /content/lyrics-sync
# /usr/local/lib/python3.12/argparse.py:2006: FutureWarning: `remote_definition` is deprecated and will be removed in 25.9. Use `conda env create --file=URL` instead.
#   action(self, namespace, argument_values, option_string)
# Channels:
#  - pytorch
#  - nvidia
#  - defaults
#  - conda-forge
# Platform: linux-64
# done
# done
#
# Downloading and Extracting Packages:
# pytorch-1.13.1       | 1.14 GB   | :   0% 0/1 [00:00<?, ?it/s]
# libcublas-11.10.3.66 | 286.1 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# mkl-2021.4.0         | 219.1 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libcurand-10.3.2.56  | 51.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# cuda-cupti-11.7.101  | 22.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.7.99   | 17.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# icu-72.1             | 11.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3.2         | 9.9 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-0.13.1    | 6.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.4.1         | 5.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.21.5    | 4.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-12.2.0  | 4.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tk-8.6.12            | 3.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# pytorch-1.13.1       | 1.14 GB   | :   0% 0.0013497476535169134/1 [00:00<01:14, 74.99s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :   1% 0.005777049089868512/1 [00:00<00:17, 17.35s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :   2% 0.018194484687040855/1 [00:00<00:05,  5.51s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :   1% 0.007612365267391675/1 [00:00<00:13, 13.15s/it]
# pytorch-1.13.1       | 1.14 GB   | :   0% 0.004516977295927888/1 [00:00<00:41, 41.71s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :   2% 0.022323658828751165/1 [00:00<00:08,  8.29s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :   5% 0.04724363353396404/1 [00:00<00:03,  4.08s/it]
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   1% 0.007938119863257887/1 [00:00<00:34, 34.97s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :   3% 0.026488754903113455/1 [00:00<00:09, 10.25s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :   4% 0.040154057254271264/1 [00:00<00:06,  6.82s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :   7% 0.06573216992795351/1 [00:00<00:03,  4.07s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   1% 0.010851436580749838/1 [00:00<00:34, 34.80s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :   6% 0.05777049089868512/1 [00:00<00:05,  6.33s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :   4% 0.041180456076180504/1 [00:00<00:08,  8.61s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  10% 0.09581913741335871/1 [00:00<00:03,  3.75s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   1% 0.014513128234845227/1 [00:00<00:31, 31.71s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :   7% 0.07396049266905737/1 [00:00<00:05,  6.28s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :   5% 0.054889069438410355/1 [00:00<00:07,  8.10s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  13% 0.12518111773044088/1 [00:00<00:03,  3.62s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  13% 0.12601748200853866/1 [00:00<00:03,  3.98s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  16% 0.1648137495987658/1 [00:00<00:02,  3.16s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :   9% 0.08993652965832338/1 [00:00<00:06,  6.66s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  15% 0.15454974208594363/1 [00:00<00:03,  3.91s/it]
# pytorch-1.13.1       | 1.14 GB   | :   2% 0.017680357877256202/1 [00:00<00:35, 36.12s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  20% 0.19659235381025802/1 [00:00<00:02,  3.27s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  11% 0.10726767692792892/1 [00:00<00:05,  6.36s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   2% 0.021368777207658857/1 [00:00<00:32, 32.87s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :   8% 0.08208783220490623/1 [00:00<00:07,  8.37s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  13% 0.1262392208526823/1 [00:00<00:05,  6.16s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  23% 0.2301834259425578/1 [00:00<00:02,  3.39s/it]
# pytorch-1.13.1       | 1.14 GB   | :   2% 0.024495915335608933/1 [00:00<00:33, 33.99s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  21% 0.20561835251434238/1 [00:00<00:03,  4.34s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  15% 0.14571001593335026/1 [00:00<00:04,  5.82s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  11% 0.1101604508032574/1 [00:00<00:06,  7.65s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  26% 0.25990789984380147/1 [00:00<00:02,  3.49s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   3% 0.027502778920176316/1 [00:00<00:35, 36.32s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  16% 0.16382570073367866/1 [00:01<00:04,  5.78s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  13% 0.12561677582919784/1 [00:01<00:06,  7.28s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  29% 0.28878655538200165/1 [00:01<00:02,  3.50s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   3% 0.03062991704812639/1 [00:01<00:34, 35.67s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  18% 0.1812281695969863/1 [00:01<00:04,  5.85s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  14% 0.13948923715990055/1 [00:01<00:06,  7.40s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  32% 0.31790687330964285/1 [00:01<00:02,  3.48s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   3% 0.03421142567329998/1 [00:01<00:32, 33.20s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  20% 0.20383711480054578/1 [00:01<00:04,  5.35s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  35% 0.34811467198976853/1 [00:01<00:02,  3.43s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  15% 0.15308861854314848/1 [00:01<00:06,  7.58s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   4% 0.03741874683017186/1 [00:01<00:31, 32.68s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  22% 0.22287998031900125/1 [00:01<00:04,  5.34s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  17% 0.1679441676846884/1 [00:01<00:06,  7.33s/it]
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   4% 0.04077307020673369/1 [00:01<00:31, 32.80s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  34% 0.3362878334485449/1 [00:01<00:02,  4.25s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  24% 0.24170888105635047/1 [00:01<00:04,  5.59s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  18% 0.18165278104691826/1 [00:01<00:06,  7.71s/it]
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   4% 0.04426103196483185/1 [00:01<00:30, 31.78s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  36% 0.3610984943854188/1 [00:01<00:02,  4.20s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  26% 0.2597532442629768/1 [00:01<00:04,  5.97s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  19% 0.19476061852474758/1 [00:01<00:06,  8.09s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  43% 0.43197152112579745/1 [00:01<00:02,  3.92s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   5% 0.04746835312170373/1 [00:01<00:30, 32.18s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  28% 0.27779760746960314/1 [00:01<00:04,  5.93s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  21% 0.2076499920446131/1 [00:01<00:06,  8.00s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  46% 0.45770856560126455/1 [00:01<00:02,  3.97s/it]
#
#
# pytorch-1.13.1       | 1.14 GB   | :   5% 0.0507558573074974/1 [00:01<00:30, 31.93s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  22% 0.22064859754346053/1 [00:01<00:06,  7.91s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  49% 0.4856205715817007/1 [00:01<00:01,  3.85s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  45% 0.4500033627425502/1 [00:01<00:01,  3.54s/it]
#
# pytorch-1.13.1       | 1.14 GB   | :   5% 0.05390972311175474/1 [00:01<00:33, 35.48s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  23% 0.23413874694772654/1 [00:01<00:05,  7.81s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  52% 0.5209032804400875/1 [00:01<00:01,  3.53s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  48% 0.4784322450660516/1 [00:01<00:01,  3.67s/it]
#
# pytorch-1.13.1       | 1.14 GB   | :   6% 0.05679631215293943/1 [00:01<00:34, 36.59s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  25% 0.24702812046759207/1 [00:02<00:05,  7.93s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  56% 0.5553401709354308/1 [00:02<00:01,  3.33s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  51% 0.5072746384051675/1 [00:02<00:01,  3.62s/it]
#
# pytorch-1.13.1       | 1.14 GB   | :   6% 0.06005708866242583/1 [00:02<00:32, 34.89s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  26% 0.26122827773524054/1 [00:02<00:05,  7.65s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  59% 0.585668800810277/1 [00:02<00:01,  3.46s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  54% 0.5350832542052469/1 [00:02<00:01,  3.78s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  34% 0.3429855441133046/1 [00:02<00:04,  6.65s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  28% 0.2752099710449252/1 [00:02<00:05,  7.75s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  62% 0.6197431977214588/1 [00:02<00:01,  3.43s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  36% 0.35938951066478314/1 [00:02<00:04,  6.49s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  56% 0.5617547147123864/1 [00:02<00:01,  3.99s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  29% 0.28913704836511883/1 [00:02<00:05,  7.58s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  66% 0.6598591543686657/1 [00:02<00:01,  3.10s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  38% 0.38107127515021555/1 [00:02<00:03,  5.82s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  59% 0.5870822644187785/1 [00:02<00:01,  4.01s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  31% 0.30759725281306183/1 [00:02<00:04,  6.87s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  40% 0.40410814991598754/1 [00:02<00:03,  5.44s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  70% 0.6963501751742576/1 [00:02<00:00,  3.12s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  63% 0.6253320333631257/1 [00:02<00:01,  3.49s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  32% 0.3228897298705294/1 [00:02<00:04,  6.77s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  42% 0.42293705065333675/1 [00:02<00:03,  5.40s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  73% 0.7307870656696008/1 [00:02<00:00,  3.06s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  67% 0.6685439344948477/1 [00:02<00:01,  3.05s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  34% 0.3394383746862889/1 [00:02<00:04,  6.54s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  44% 0.44255048892140886/1 [00:02<00:02,  5.31s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  78% 0.7777904004158764/1 [00:02<00:00,  2.72s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  71% 0.7070004589470023/1 [00:02<00:00,  2.91s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  35% 0.35478546773324743/1 [00:02<00:04,  6.83s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  46% 0.4640182886257351/1 [00:02<00:02,  5.29s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  81% 0.8148855771950708/1 [00:02<00:00,  2.93s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  74% 0.7418387620125294/1 [00:02<00:00,  3.38s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  37% 0.37406491202355474/1 [00:02<00:04,  6.50s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  49% 0.48741177136001745/1 [00:02<00:02,  5.03s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  85% 0.8545182090633957/1 [00:02<00:00,  2.80s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  77% 0.7728520881836217/1 [00:02<00:00,  3.34s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  39% 0.39443667610368116/1 [00:02<00:03,  6.21s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  51% 0.5126596155305538/1 [00:02<00:02,  4.76s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  89% 0.8907675674795466/1 [00:02<00:00,  2.81s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  80% 0.8038654143547141/1 [00:03<00:00,  3.55s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  41% 0.4105483930035131/1 [00:03<00:03,  6.31s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  54% 0.5362670630459425/1 [00:03<00:02,  4.60s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  93% 0.9302793681531509/1 [00:03<00:00,  2.72s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  83% 0.8329145632016373/1 [00:03<00:00,  3.54s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  43% 0.4299370692728023/1 [00:03<00:03,  5.94s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  56% 0.5580914707187791/1 [00:03<00:02,  4.65s/it]
#
#
#
# libnpp-11.7.4.75     | 129.3 MB  | :  97% 0.9741410918366935/1 [00:03<00:00,  2.58s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  86% 0.8627907340797896/1 [00:03<00:00,  3.49s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  45% 0.4486157376787091/1 [00:03<00:03,  5.77s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  58% 0.5816989182341678/1 [00:03<00:01,  4.53s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  89% 0.8919432606806165/1 [00:04<00:01, 12.37s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :   0% 0.00016697970094918033/1 [00:07<13:18:05, 47893.77s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   6% 0.06297040537991778/1 [00:08<10:02, 643.16s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  91% 0.9132390779847666/1 [00:08<00:04, 54.89s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  60% 0.6038799338755148/1 [00:08<00:28, 72.35s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  47% 0.46603823832632396/1 [00:08<00:48, 91.65s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   7% 0.06643163946170867/1 [00:08<06:54, 444.27s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  94% 0.9350517840584348/1 [00:08<00:02, 42.25s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  48% 0.4783814519512799/1 [00:08<00:37, 72.62s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  62% 0.6195706844899724/1 [00:08<00:21, 57.49s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   7% 0.06891731335828438/1 [00:08<05:20, 344.04s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  95% 0.9535564020071866/1 [00:08<00:01, 33.65s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  49% 0.49094312953419966/1 [00:08<00:28, 56.71s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  64% 0.6356893646666426/1 [00:08<00:16, 44.63s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   7% 0.07196426845731266/1 [00:08<03:52, 250.43s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | :  98% 0.9754724858347585/1 [00:08<00:00, 25.56s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  65% 0.6522359744055253/1 [00:08<00:11, 34.24s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  50% 0.5048155908649024/1 [00:08<00:21, 42.94s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   7% 0.07498449588003367/1 [00:08<02:51, 185.15s/it]
#
#
# libcusparse-11.7.4.9 | 151.1 MB  | : 100% 0.999249369232596/1 [00:08<00:00, 19.11s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  67% 0.6699237296436411/1 [00:08<00:08, 26.00s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  52% 0.5176503483952769/1 [00:08<00:16, 33.51s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   8% 0.07767062734891386/1 [00:08<02:14, 145.30s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  53% 0.529884330041251/1 [00:09<00:12, 27.32s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  69% 0.685828445039205/1 [00:09<00:06, 21.27s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   8% 0.08027657578887226/1 [00:09<01:50, 120.30s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  70% 0.7004493717481316/1 [00:09<00:05, 18.42s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  54% 0.5412990718448607/1 [00:09<00:10, 23.93s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   8% 0.0826553389802189/1 [00:09<01:34, 102.67s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  71% 0.7135725449893143/1 [00:09<00:04, 15.74s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  55% 0.5513484139111966/1 [00:09<00:09, 20.62s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   9% 0.0851009213623337/1 [00:09<01:18, 85.40s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  73% 0.7266243966367951/1 [00:09<00:03, 13.90s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  56% 0.5612339080090595/1 [00:09<00:07, 18.03s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   9% 0.08738613768660491/1 [00:09<01:07, 74.34s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  74% 0.7413166449394236/1 [00:09<00:03, 11.86s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  57% 0.5734678896550336/1 [00:09<00:06, 15.04s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   9% 0.09025936288963597/1 [00:09<00:57, 63.21s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  76% 0.7583625058342208/1 [00:09<00:02, 10.05s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  59% 0.5864664951538809/1 [00:09<00:05, 12.86s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :   9% 0.09337313717943241/1 [00:09<00:47, 52.77s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  60% 0.5982089328944364/1 [00:09<00:04, 11.76s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  77% 0.774409864417189/1 [00:09<00:02,  9.26s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  10% 0.09671409671784062/1 [00:09<00:40, 45.00s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  61% 0.6102790665719376/1 [00:09<00:04, 10.84s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  79% 0.7917410116867944/1 [00:09<00:01,  8.36s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  10% 0.0995205027301035/1 [00:09<00:39, 43.96s/it]
# pytorch-1.13.1       | 1.14 GB   | :  10% 0.1022066341989837/1 [00:09<00:38, 43.21s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :  52% 0.5173031135405607/1 [00:10<00:01,  3.46s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  81% 0.8065759031768271/1 [00:10<00:01,  8.41s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  82% 0.8200556843865204/1 [00:10<00:01,  8.26s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  63% 0.6324531583052656/1 [00:10<00:04, 11.23s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  10% 0.1048125826389421/1 [00:10<00:41, 45.82s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  83% 0.8341773599395323/1 [00:10<00:01,  8.05s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  64% 0.6440317480773482/1 [00:10<00:03, 10.64s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  11% 0.10744525875520776/1 [00:10<00:39, 43.83s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  65% 0.6542995541016479/1 [00:10<00:03, 10.60s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :  61% 0.6108117460721016/1 [00:10<00:01,  3.45s/it]
#
# pytorch-1.13.1       | 1.14 GB   | :  11% 0.10989084113732256/1 [00:10<00:39, 43.96s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  67% 0.6657142959052575/1 [00:10<00:03, 10.23s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  11% 0.11257697260620275/1 [00:10<00:37, 41.92s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  86% 0.863205248576279/1 [00:10<00:01,  7.98s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  68% 0.679914453172906/1 [00:10<00:03,  9.39s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :  68% 0.6846167738916393/1 [00:10<00:00,  3.12s/it]
#
# pytorch-1.13.1       | 1.14 GB   | :  12% 0.11602484284984002/1 [00:10<00:34, 38.92s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  69% 0.6938415304930996/1 [00:10<00:02,  8.67s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :  73% 0.7285324352412738/1 [00:10<00:00,  2.85s/it]
#
# pytorch-1.13.1       | 1.14 GB   | :  12% 0.11865751896610569/1 [00:10<00:36, 41.03s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  71% 0.7059662801600918/1 [00:10<00:02,  8.55s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :  76% 0.7642660912443984/1 [00:10<00:00,  2.85s/it]
#
# pytorch-1.13.1       | 1.14 GB   | :  12% 0.1214371973020613/1 [00:10<00:35, 40.88s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :   0% 0.00019847179143347583/1 [00:11<15:59:19, 57570.92s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :   0% 0.004961794785836896/1 [00:14<36:28, 2199.33s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :   1% 0.005755681951570799/1 [00:14<30:05, 1816.41s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :   1% 0.007938871657339034/1 [00:14<17:36, 1064.50s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  72% 0.717927181858611/1 [00:14<00:27, 98.23s/it]
#
# pytorch-1.13.1       | 1.14 GB   | :  12% 0.12392287119863701/1 [00:14<06:29, 444.17s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :   2% 0.016076215106111545/1 [00:14<05:29, 334.94s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  13% 0.12695646245951164/1 [00:14<04:31, 310.82s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  73% 0.7297788515781484/1 [00:14<00:19, 72.19s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  94% 0.9446545085840549/1 [00:14<00:03, 57.83s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :   6% 0.05636598876710714/1 [00:14<00:55, 58.83s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  13% 0.12992323452961813/1 [00:14<03:15, 224.42s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  74% 0.7391728017705927/1 [00:14<00:14, 56.95s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  96% 0.9576350386378335/1 [00:14<00:01, 44.38s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  10% 0.1010221418396392/1 [00:14<00:24, 26.72s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :  87% 0.873136856263264/1 [00:14<00:02, 17.89s/it]
# pytorch-1.13.1       | 1.14 GB   | :  13% 0.1323153615591184/1 [00:14<02:33, 176.76s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  98% 0.975893366625566/1 [00:14<00:00, 30.76s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  14% 0.1411134437092013/1 [00:14<00:14, 16.51s/it]
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  14% 0.13623096613813282/1 [00:14<01:42, 119.01s/it]
#
# mkl-2021.4.0         | 219.1 MB  | :  99% 0.9895871126163654/1 [00:14<00:00, 24.45s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  18% 0.17763225333296087/1 [00:14<00:09, 11.63s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  76% 0.7586707100188639/1 [00:14<00:08, 35.61s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :  93% 0.9329155892030705/1 [00:14<00:00, 11.47s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  22% 0.21772355520252298/1 [00:15<00:06,  8.37s/it]
# pytorch-1.13.1       | 1.14 GB   | :  14% 0.13906409982670298/1 [00:15<01:24, 98.04s/it]
#
#
#
#
# libcufft-10.7.2.124  | 93.6 MB   | :  97% 0.973157697131823/1 [00:15<00:00,  8.38s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  25% 0.25265459049481476/1 [00:15<00:05,  6.74s/it]
# pytorch-1.13.1       | 1.14 GB   | :  14% 0.14171013978112226/1 [00:15<01:12, 84.84s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  79% 0.7946080311039126/1 [00:15<00:03, 17.58s/it]
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  14% 0.14479718639461145/1 [00:15<00:59, 69.51s/it]
# pytorch-1.13.1       | 1.14 GB   | :  15% 0.14753677321610617/1 [00:15<00:52, 61.37s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  33% 0.33323413781680594/1 [00:15<00:03,  5.07s/it]
# pytorch-1.13.1       | 1.14 GB   | :  15% 0.15091782426897526/1 [00:15<00:43, 51.23s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  36% 0.36419573728042814/1 [00:15<00:02,  4.61s/it]
# pytorch-1.13.1       | 1.14 GB   | :  15% 0.15365741109047001/1 [00:15<00:40, 47.42s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  40% 0.4023023212356555/1 [00:15<00:02,  3.98s/it]
# pytorch-1.13.1       | 1.14 GB   | :  16% 0.156423725588272/1 [00:15<00:37, 44.71s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  44% 0.44497375639385284/1 [00:15<00:01,  3.43s/it]
# pytorch-1.13.1       | 1.14 GB   | :  16% 0.15969786593591204/1 [00:15<00:33, 40.45s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  49% 0.4943932324607883/1 [00:15<00:01,  2.97s/it]
# pytorch-1.13.1       | 1.14 GB   | :  16% 0.16329273839923925/1 [00:15<00:30, 36.27s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  53% 0.5336906471646166/1 [00:15<00:01,  2.95s/it]
# pytorch-1.13.1       | 1.14 GB   | :  17% 0.1666203340994938/1 [00:16<00:28, 34.68s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  57% 0.5743773644084791/1 [00:16<00:01,  2.84s/it]
# pytorch-1.13.1       | 1.14 GB   | :  17% 0.16972074455113664/1 [00:16<00:29, 35.24s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  61% 0.6124839483637065/1 [00:16<00:01,  2.97s/it]
# pytorch-1.13.1       | 1.14 GB   | :  17% 0.1727142442975504/1 [00:16<00:29, 36.17s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  65% 0.6549569117304702/1 [00:16<00:00,  2.85s/it]
# pytorch-1.13.1       | 1.14 GB   | :  18% 0.17633584443718486/1 [00:16<00:27, 33.33s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  70% 0.6964375161400668/1 [00:16<00:00,  2.77s/it]
# pytorch-1.13.1       | 1.14 GB   | :  18% 0.1794362548888277/1 [00:16<00:31, 38.92s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  73% 0.7337502129295602/1 [00:16<00:00,  3.00s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  94% 0.9409242669501827/1 [00:16<00:00,  9.69s/it]
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  18% 0.18217584171032242/1 [00:16<00:34, 41.62s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  96% 0.9581283036398337/1 [00:16<00:00,  8.37s/it]
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  18% 0.18471497095951264/1 [00:16<00:34, 42.09s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  97% 0.9706899812227535/1 [00:16<00:00,  8.48s/it]
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  19% 0.18733428323762466/1 [00:16<00:33, 41.63s/it]
# pytorch-1.13.1       | 1.14 GB   | :  19% 0.19040796601296023/1 [00:16<00:31, 38.76s/it]
#
#
#
#
#
# libcusolver-11.4.0.1 | 78.7 MB   | :  91% 0.9149549585083236/1 [00:16<00:00,  2.60s/it]
# libcublas-11.10.3.66 | 286.1 MB  | :  99% 0.9948302485777558/1 [00:17<00:00,  8.73s/it]
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  20% 0.20345107205090585/1 [00:17<00:26, 33.68s/it]
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  21% 0.2064579356354732/1 [00:17<00:29, 37.17s/it]
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  21% 0.2092242501332752/1 [00:17<00:29, 37.66s/it]
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  21% 0.21216429452707442/1 [00:17<00:28, 36.79s/it]
#
#
#
#
#
#
#
# libcurand-10.3.2.56  | 51.7 MB   | :   0% 0.00030210613557942167/1 [00:18<17:05:37, 61556.27s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  18% 0.1831604542965005/1 [00:20<00:56, 69.46s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  21% 0.21493060902487643/1 [00:21<04:43, 361.13s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :   0% 0.000384206171635243/1 [00:21<15:12:17, 54758.49s/it]
#
#
#
#
#
#
#
#
#
# cuda-cupti-11.7.101  | 22.9 MB   | :   0% 0.0006828059590823195/1 [00:21<8:33:30, 30831.83s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  24% 0.238490174865235/1 [00:21<00:33, 44.53s/it]
#
#
#
#
#
#
#
# libcurand-10.3.2.56  | 51.7 MB   | :   7% 0.06918230504768756/1 [00:21<02:29, 160.40s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :   9% 0.0856779762746592/1 [00:21<02:38, 173.37s/it]
#
#
#
#
#
#
#
#
#
# cuda-cupti-11.7.101  | 22.9 MB   | :  14% 0.13929241565279318/1 [00:21<01:31, 106.67s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  31% 0.30608510442703873/1 [00:21<00:19, 27.66s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  22% 0.21689509323346043/1 [00:21<03:56, 301.99s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  20% 0.1955609413623387/1 [00:21<00:49, 61.75s/it]
#
#
#
#
#
#
#
#
#
# cuda-cupti-11.7.101  | 22.9 MB   | :  28% 0.27790202534650404/1 [00:21<00:32, 44.61s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  38% 0.3772233165868403/1 [00:21<00:11, 17.93s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  22% 0.21983513762725965/1 [00:21<02:48, 215.64s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  29% 0.2931493089576904/1 [00:21<00:24, 34.54s/it]
#
#
#
#
#
#
#
#
#
# cuda-cupti-11.7.101  | 22.9 MB   | :  46% 0.459528410462401/1 [00:21<00:11, 21.54s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  44% 0.43773168095264847/1 [00:21<00:07, 12.88s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  22% 0.22304245878413154/1 [00:21<01:59, 154.06s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  38% 0.37882728523234965/1 [00:21<00:13, 22.49s/it]
#
#
#
#
#
#
#
#
#
# cuda-cupti-11.7.101  | 22.9 MB   | :  60% 0.6049660797469351/1 [00:21<00:05, 13.73s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  23% 0.22580877328193352/1 [00:21<01:32, 119.66s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  50% 0.4963321239195348/1 [00:21<00:04,  9.72s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  46% 0.4641210553353736/1 [00:21<00:08, 15.46s/it]
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  23% 0.22830781101666286/1 [00:21<01:17, 100.70s/it]
#
#
#
#
#
#
#
# libcurand-10.3.2.56  | 51.7 MB   | :  39% 0.3860916412705009/1 [00:21<00:07, 11.44s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  55% 0.5497539230893475/1 [00:21<00:03,  7.59s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  23% 0.23065984653170224/1 [00:21<01:08, 88.45s/it]
#
#
#
#
#
#
#
#
#
# cuda-cupti-11.7.101  | 22.9 MB   | :  88% 0.8760400455026158/1 [00:21<00:00,  6.81s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  60% 0.6009952406603922/1 [00:21<00:02,  6.26s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  54% 0.539041258804246/1 [00:21<00:05, 11.47s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  23% 0.23314552042827794/1 [00:21<00:57, 75.56s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  63% 0.6258718535938109/1 [00:21<00:03,  8.06s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  67% 0.6710432120208097/1 [00:21<00:01,  4.57s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  24% 0.23604547330761624/1 [00:21<00:47, 62.21s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  70% 0.6984868200328719/1 [00:21<00:01,  6.18s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  73% 0.7288259743881582/1 [00:22<00:01,  3.75s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  24% 0.2388786069961864/1 [00:22<00:40, 53.83s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  77% 0.7703333741286623/1 [00:22<00:01,  4.82s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  78% 0.7830654541575087/1 [00:22<00:00,  3.27s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  24% 0.24149791927429842/1 [00:22<00:37, 49.57s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  85% 0.8479430207989814/1 [00:22<00:00,  3.74s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  84% 0.8356695727277834/1 [00:22<00:00,  2.95s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  24% 0.2444646913444049/1 [00:22<00:34, 45.68s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  92% 0.9213263995813128/1 [00:22<00:00,  3.21s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  89% 0.8866383300989822/1 [00:22<00:00,  2.86s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  25% 0.24713745897513148/1 [00:22<00:34, 46.00s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  93% 0.9346089252718752/1 [00:22<00:00,  2.65s/it]
#
#
#
#
#
#
#
#
# llvm-openmp-16.0.1   | 40.7 MB   | :  99% 0.9881782734458451/1 [00:22<00:00,  2.80s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  25% 0.2495964051953999/1 [00:22<00:36, 49.19s/it]
#
#
#
#
#
#
# python-3.7.12        | 57.3 MB   | :  98% 0.9820344000450763/1 [00:22<00:00,  2.86s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  25% 0.2518415300052102/1 [00:22<00:38, 51.02s/it]
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-11.7.99   | 17.3 MB   | :   0% 0.0009030257591074066/1 [00:22<6:59:29, 25192.49s/it]
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  25% 0.25412674632948146/1 [00:22<00:37, 50.04s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  26% 0.2571202460758952/1 [00:22<00:33, 45.26s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  26% 0.2596192838106245/1 [00:23<00:32, 44.33s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  26% 0.26194459164935663/1 [00:23<00:32, 44.13s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  26% 0.2643901740314714/1 [00:23<00:31, 43.19s/it]
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  29% 0.28684142212957453/1 [00:24<00:26, 36.94s/it]
#
#
#
#
#
#
#
#
#
#
#
# icu-72.1             | 11.4 MB   | :   0% 0.0013659177184638827/1 [00:24<4:53:25, 17629.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  29% 0.2897146473326056/1 [00:24<00:27, 39.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# icu-72.1             | 11.4 MB   | :  29% 0.29230639175127093/1 [00:24<00:41, 58.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  29% 0.29238741496333215/1 [00:24<00:28, 39.90s/it]
#
#
#
#
#
#
#
#
#
#
#
# icu-72.1             | 11.4 MB   | :  56% 0.5613921822886558/1 [00:24<00:11, 25.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-1.13.1       | 1.14 GB   | :  29% 0.29491318037436876/1 [00:24<00:28, 40.60s/it]
#
#
#
#
#
#
#
#
#
#
#
# icu-72.1             | 11.4 MB   | :  86% 0.863259998069174/1 [00:24<00:01, 13.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ffmpeg-4.3.2         | 9.9 MB    | :  99% 0.9936885375298317/1 [00:24<00:00, 11.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-0.13.1    | 6.5 MB    | :   0% 0.002394383487171693/1 [00:24<2:51:58, 10343.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.4.1         | 5.7 MB    | :   0% 0.0027367024639509104/1 [00:24<2:30:28, 9053.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-12.2.0  | 4.3 MB    | :   0% 0.003642462432659798/1 [00:27<2:07:20, 7668.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.21.5    | 4.8 MB    | :   0% 0.0032263070048512755/1 [00:27<2:23:51, 8659.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.4.1         | 5.7 MB    | :   3% 0.030103727103460015/1 [00:27<11:21, 702.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-0.13.1    | 6.5 MB    | :   7% 0.07422588810232249/1 [00:28<04:19, 280.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-12.2.0  | 4.3 MB    | :   4% 0.040067086759257776/1 [00:28<08:04, 504.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.21.5    | 4.8 MB    | :   5% 0.054847219082471685/1 [00:28<05:44, 364.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.4.1         | 5.7 MB    | :   6% 0.06294415667087094/1 [00:28<04:14, 271.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# torchaudio-0.13.1    | 6.5 MB    | :  10% 0.1029584899483828/1 [00:28<02:42, 181.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libstdcxx-ng-12.2.0  | 4.3 MB    | :   8% 0.08377663595117535/1 [00:28<02:58, 195.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nettle-3.4.1         | 5.7 MB    | :   8% 0.08483777638247822/1 [00:28<02:38, 173.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# numpy-base-1.21.5    | 4.8 MB    | :  10% 0.10324182415524082/1 [00:28<02:25, 162.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# Requirement already satisfied: ipywidgets in /usr/local/envs/lsync/lib/python3.7/site-packages (from jupyter==1.0.0->-r /content/lyrics-sync/condaenv.gzxz2ixp.requirements.txt (line 63)) (8.0.6)
# Requirement already satisfied: entrypoints in /usr/local/envs/lsync/lib/python3.7/site-packages (from jupyter-client==7.4.9->-r /content/lyrics-sync/condaenv.gzxz2ixp.requirements.txt (line 64)) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/envs/lsync/lib/python3.7/site-packages (from jupyter-client==7.4.9->-r /content/lyrics-sync/condaenv.gzxz2ixp.requirements.txt (line 64)) (2.8.2)
# Requirement already satisfied: ipython-genutils in /usr/local/envs/lsync/lib/python3.7/site-packages (from nbclassic==0.5.5->-r /content/lyrics-sync/condaenv.gzxz2ixp.requirements.txt (line 82)) (0.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/envs/lsync/lib/python3.7/site-packages (from terminado==0.17.1->-r /content/lyrics-sync/condaenv.gzxz2ixp.requirements.txt (line 145)) (0.7.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /usr/local/envs/lsync/lib/python3.7/site-packages (from ipywidgets->jupyter==1.0.0->-r /content/lyrics-sync/condaenv.gzxz2ixp.requirements.txt (line 63)) (3.0.7)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /usr/local/envs/lsync/lib/python3.7/site-packages (from ipywidgets->jupyter==1.0.0->-r /content/lyrics-sync/condaenv.gzxz2ixp.requirements.txt (line 63)) (4.0.7)
# Building wheels for collected packages: antlr4-python3-runtime, audioread, demucs, docopt, dora-search, future, jieba, julius, pathtools, soxr, treetable
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=ce4a008893fb3a86c5607ba1c32da0238fea9e0ab2ba8e0f2a3dfe2a34b4db29
#   Stored in directory: /root/.cache/pip/wheels/8b/8d/53/2af8772d9aec614e3fc65e53d4a993ad73c61daa8bbd85a873
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=c071df1bcd0c47fdf0f0506b78b1eb5ffaa9c81e29453afc1e066d1b2826e87d
#   Stored in directory: /root/.cache/pip/wheels/71/a4/fa/24175dada88ca37d7fd22ffec10b33cb0a4909d7d07f04101f
#   Building wheel for demucs (setup.py): started
#   Building wheel for demucs (setup.py): finished with status 'done'
#   Created wheel for demucs: filename=demucs-4.0.0-py3-none-any.whl size=76505 sha256=fa9324f2c90ba3e7ba5a773161cd42d4848fb1cc09fcbf596f14b5d92e7d7e6c
#   Stored in directory: /root/.cache/pip/wheels/39/55/bc/deb86163801e6f1d839ee90255a7b4854a8f20788ca3775eaa
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=8ff49301aa2ff6a2ba56dd4e15e3ce11a281dcf6ef2e702701ca77f26b28247e
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for dora-search (pyproject.toml): started
#   Building wheel for dora-search (pyproject.toml): finished with status 'done'
#   Created wheel for dora-search: filename=dora_search-0.1.11-py3-none-any.whl size=74990 sha256=547bd4da349044260b7a7538e720b23f658000c2e401fcd74c2fbd47693586ea
#   Stored in directory: /root/.cache/pip/wheels/65/eb/b8/e8133b705e900f151d5d26549d202b93fa83eaba59a6e9955e
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492022 sha256=6fe4ac571ac5b33a484adc33728c4d0717bd1ea4eb8af5579fa464b49995e1a2
#   Stored in directory: /root/.cache/pip/wheels/fa/cd/1f/c6b7b50b564983bf3011e8fc75d06047ddc50c07f6e3660b00
#   Building wheel for jieba (setup.py): started
#   Building wheel for jieba (setup.py): finished with status 'done'
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314458 sha256=ee7fdfa487cb57509ec336736bc8c10c7bb798b79243dd32a00c3680c4404a47
#   Stored in directory: /root/.cache/pip/wheels/24/aa/17/5bc7c72e9a37990a9620cc3aad0acad1564dcff6dbc2359de3
#   Building wheel for julius (setup.py): started
#   Building wheel for julius (setup.py): finished with status 'done'
#   Created wheel for julius: filename=julius-0.2.7-py3-none-any.whl size=21878 sha256=dc53c23ee72c6a380940132f87b4afc9819cdf47519b0d7bd92b0b93c46cc0bb
#   Stored in directory: /root/.cache/pip/wheels/44/52/2c/7dd069f82c7f905f40b190a8039ec2a17fdd4bb009c57c6664
#   Building wheel for pathtools (setup.py): started
#   Building wheel for pathtools (setup.py): finished with status 'done'
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=e5a60725fa1732e4a7e866e9abf499a0268a33ae69022f3bab6a6c8cb79265ad
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
#   Building wheel for soxr (pyproject.toml): started
#   Building wheel for soxr (pyproject.toml): finished with status 'done'
#   Created wheel for soxr: filename=soxr-0.3.5-cp37-cp37m-linux_x86_64.whl size=1203012 sha256=6528334dc9fe44b2a5177721ca1b8551d6882bc6e5d5059d1cf0517986748f8a
#   Stored in directory: /root/.cache/pip/wheels/50/e7/40/7ec6598e9ef8d9ca7d55228b0381052c3d54a131d555433657
#   Building wheel for treetable (setup.py): started
#   Building wheel for treetable (setup.py): finished with status 'done'
#   Created wheel for treetable: filename=treetable-0.2.5-py3-none-any.whl size=7332 sha256=9719e2b0d97b56c9bafdd6b81d5b3674b5e990c8c07990764b3ab5c7df773f43
#   Stored in directory: /root/.cache/pip/wheels/49/47/17/9a3302620cfb927cd6eb60bc80133c12af5b37f05ee5dc5656
# Successfully built antlr4-python3-runtime audioread demucs docopt dora-search future jieba julius pathtools soxr treetable
# Installing collected packages: youtube-dl, webencodings, wcwidth, tokenizers, sortedcontainers, sentencepiece, send2trash, pytz, pygtrie, pydub, pathtools, msgpack, mistune, lameenc, jieba, fastjsonschema, docopt, appdirs, antlr4-python3-runtime, zipp, xxhash, websocket-client, urllib3, treetable, traitlets, tinycss2, threadpoolctl, terminado, soxr, soupsieve, sniffio, smmap, simplejson, setuptools, setproctitle, scipy, ruamel-yaml-clib, retrying, regex, rapidfuzz, pyzmq, pyyaml, pyrsistent, pyparsing, pygments, pycparser, pyarrow, psutil, protobuf, prompt-toolkit, prometheus-client, pkgutil-resolve-name, pillow, pfzy, pandocfilters, packaging, num2words, multidict, markupsafe, llvmlite, lazy-loader, kiwisolver, jupyterlab-pygments, joblib, jedi, idna, future, fsspec, frozenlist, fonttools, filelock, exceptiongroup, einops, docker-pycreds, dill, defusedxml, debugpy, dali-dataset, cython, cycler, colorlog, cloudpickle, charset-normalizer, bleach, audioread, attrs, asynctest, async-timeout, yarl, submitit, sentry-sdk, scikit-learn, ruamel-yaml, requests, qtpy, pyaml, pandas, omegaconf, multiprocess, matplotlib, jupyter-core, julius, jinja2, inquirerpy, importlib-resources, importlib-metadata, hypothesis, gitdb, ffmpeg-python, diffq, cffi, beautifulsoup4, anyio, aiosignal, accelerate, yarg, stempeg, soundfile, seaborn, responses, pyctcdecode, pooch, openunmix, numba, jupyter-client, jsonschema, ipython, hyperpyyaml, hydra-core, huggingface-hub, gitpython, dora-search, click, argon2-cffi-bindings, aiohttp, wandb, transformers, speechbrain, pipreqs, nbformat, musdb, librosa, jiwer, ipykernel, hydra-colorlog, demucs, argon2-cffi, qtconsole, nbclient, museval, jupyter-console, datasets, nbconvert, evaluate, jupyter-server, notebook-shim, nbclassic, notebook, jupyter
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 65.6.3
#     Uninstalling setuptools-65.6.3:
#       Successfully uninstalled setuptools-65.6.3
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.0
#     Uninstalling pyzmq-23.2.0:
#       Successfully uninstalled pyzmq-23.2.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.36
#     Uninstalling prompt-toolkit-3.0.36:
#       Successfully uninstalled prompt-toolkit-3.0.36
#   Attempting uninstall: jedi
#     Found existing installation: jedi 0.18.1
#     Uninstalling jedi-0.18.1:
#       Successfully uninstalled jedi-0.18.1
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.5.1
#     Uninstalling debugpy-1.5.1:
#       Successfully uninstalled debugpy-1.5.1
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.5.0
#     Uninstalling jupyter-core-4.5.0:
#       Successfully uninstalled jupyter-core-4.5.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 5.3.4
#     Uninstalling jupyter-client-5.3.4:
#       Successfully uninstalled jupyter-client-5.3.4
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.31.1
#     Uninstalling ipython-7.31.1:
#       Successfully uninstalled ipython-7.31.1
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.9.1
#     Uninstalling ipykernel-6.9.1:
#       Successfully uninstalled ipykernel-6.9.1
# Successfully installed accelerate-0.19.0 aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 anyio-3.6.2 appdirs-1.4.4 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 async-timeout-4.0.2 asynctest-0.13.0 attrs-22.2.0 audioread-3.0.0 beautifulsoup4-4.12.2 bleach-6.0.0 cffi-1.15.1 charset-normalizer-3.1.0 click-8.1.3 cloudpickle-2.2.1 colorlog-6.7.0 cycler-0.11.0 cython-0.29.34 dali-dataset-1.1 datasets-2.12.0 debugpy-1.6.7 defusedxml-0.7.1 demucs-4.0.0 diffq-0.2.3 dill-0.3.6 docker-pycreds-0.4.0 docopt-0.6.2 dora-search-0.1.11 einops-0.6.0 evaluate-0.4.0 exceptiongroup-1.1.1 fastjsonschema-2.16.3 ffmpeg-python-0.2.0 filelock-3.11.0 fonttools-4.38.0 frozenlist-1.3.3 fsspec-2023.1.0 future-0.18.3 gitdb-4.0.10 gitpython-3.1.31 huggingface-hub-0.14.1 hydra-colorlog-1.2.0 hydra-core-1.3.2 hyperpyyaml-1.2.0 hypothesis-6.71.0 idna-3.4 importlib-metadata-4.13.0 importlib-resources-5.12.0 inquirerpy-0.3.4 ipykernel-6.16.2 ipython-7.34.0 jedi-0.18.2 jieba-0.42.1 jinja2-3.1.2 jiwer-3.0.1 joblib-1.2.0 jsonschema-4.17.3 julius-0.2.7 jupyter-1.0.0 jupyter-client-7.4.9 jupyter-console-6.6.3 jupyter-core-4.12.0 jupyter-server-1.24.0 jupyterlab-pygments-0.2.2 kiwisolver-1.4.4 lameenc-1.4.2 lazy-loader-0.2 librosa-0.10.0.post2 llvmlite-0.39.1 markupsafe-2.1.2 matplotlib-3.5.3 mistune-2.0.5 msgpack-1.0.5 multidict-6.0.4 multiprocess-0.70.14 musdb-0.4.0 museval-0.4.0 nbclassic-0.5.5 nbclient-0.7.3 nbconvert-7.3.1 nbformat-5.8.0 notebook-6.5.4 notebook-shim-0.2.2 num2words-0.5.12 numba-0.56.4 omegaconf-2.3.0 openunmix-1.2.1 packaging-23.1 pandas-1.3.5 pandocfilters-1.5.0 pathtools-0.1.2 pfzy-0.3.4 pillow-9.5.0 pipreqs-0.4.13 pkgutil-resolve-name-1.3.10 pooch-1.6.0 prometheus-client-0.16.0 prompt-toolkit-3.0.38 protobuf-4.22.3 psutil-5.9.4 pyaml-21.10.1 pyarrow-11.0.0 pycparser-2.21 pyctcdecode-0.5.0 pydub-0.25.1 pygments-2.15.0 pygtrie-2.5.0 pyparsing-3.0.9 pyrsistent-0.19.3 pytz-2023.3 pyyaml-6.0 pyzmq-25.0.2 qtconsole-5.4.2 qtpy-2.3.1 rapidfuzz-2.13.7 regex-2022.10.31 requests-2.28.2 responses-0.18.0 retrying-1.3.4 ruamel-yaml-0.17.24 ruamel-yaml-clib-0.2.7 scikit-learn-1.0.2 scipy-1.7.3 seaborn-0.12.2 send2trash-1.8.0 sentencepiece-0.1.99 sentry-sdk-1.19.1 setproctitle-1.3.2 setuptools-67.6.1 simplejson-3.19.1 smmap-5.0.0 sniffio-1.3.0 sortedcontainers-2.4.0 soundfile-0.12.1 soupsieve-2.4 soxr-0.3.5 speechbrain-0.5.14 stempeg-0.2.3 submitit-1.4.5 terminado-0.17.1 threadpoolctl-3.1.0 tinycss2-1.2.1 tokenizers-0.13.3 traitlets-5.9.0 transformers-4.29.1 treetable-0.2.5 urllib3-1.26.15 wandb-0.14.2 wcwidth-0.2.6 webencodings-0.5.1 websocket-client-1.5.1 xxhash-3.2.0 yarg-0.1.9 yarl-1.8.2 youtube-dl-2021.12.17 zipp-3.15.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate lsync
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# Downloading: "https://dl.fbaipublicfiles.com/demucs/hybrid_transformer/955717e8-8726e21a.th" to /root/.cache/torch/hub/checkpoints/955717e8-8726e21a.th
# 100%|██████████| 80.2M/80.2M [00:00<00:00, 117MB/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/158 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/162 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-960h-lv60-self and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Saving chord sheet to que_pais_e_este.txt...
# Saved as /content/chord_sheets/que_pais_e_este.txt!
# Saving chord sheet to infiel.txt...
# Saved as /content/chord_sheets/infiel.txt!
# Saving chord sheet to tocando_em_frente.txt...
# Saved as /content/chord_sheets/tocando_em_frente.txt!
# Saving chord sheet to petrolina_juazeiro.txt...
# Saved as /content/chord_sheets/petrolina_juazeiro.txt!
# Saving chord sheet to naquela_mesa.txt...
# Saved as /content/chord_sheets/naquela_mesa.txt!
# Saving chord sheet to uma_carta.txt...
# Saved as /content/chord_sheets/uma_carta.txt!
# Saving chord sheet to como_vai_voce.txt...
# Saved as /content/chord_sheets/como_vai_voce.txt!
# Saving chord sheet to evidencias.txt...
# Saved as /content/chord_sheets/evidencias.txt!
# Saving chord sheet to sozinho.txt...
# Saved as /content/chord_sheets/sozinho.txt!
# Saving chord sheet to garota_de_ipanema.txt...
# Saved as /content/chord_sheets/garota_de_ipanema.txt!
# Saving chord sheet to joao_e_maria.txt...
# Saved as /content/chord_sheets/joao_e_maria.txt!
# Saving chord sheet to aguas_de_marco.txt...
# Saved as /content/chord_sheets/aguas_de_marco.txt!
# Saving chord sheet to corcovado.txt...
# Saved as /content/chord_sheets/corcovado.txt!
# Saving chord sheet to summertime_sadness.txt...
# Saved as /content/chord_sheets/summertime_sadness.txt!
# Saving chord sheet to beautiful_things.txt...
# Saved as /content/chord_sheets/beautiful_things.txt!
# Saving chord sheet to it_s_my_life.txt...
# Saved as /content/chord_sheets/it_s_my_life.txt!
# Saving chord sheet to always_on_my_mind.txt...
# Saved as /content/chord_sheets/always_on_my_mind.txt!
# Saving chord sheet to love_me_tender.txt...
# Saved as /content/chord_sheets/love_me_tender.txt!
# Saving chord sheet to my_sacrifice.txt...
# Saved as /content/chord_sheets/my_sacrifice.txt!
# Saving chord sheet to wherever_you_will_go_fotos.txt...
# Saved as /content/chord_sheets/wherever_you_will_go_fotos.txt!

# %%
comparisons = []
for chord_sheet, song_name, evaluation_path in zip(chord_sheets, song_names, evaluation_paths):
    name = song_name.upper().replace("_", " ")
    print(f"------------EVALUATING \'{name}\' CHORD SHEET----------------\n")

    comparison = compare_chords(chord_sheet, evaluation_path)
    comparisons.append(comparison)

    for key, value in comparison.items():
        if isinstance(value, dict):  # Se o valor for um dicionário, iteramos sobre ele
            print(f"{key}:")
            for sub_key, sub_value in value.items():
                print(f"  {sub_key}: {sub_value}")
        else:
            print(f"{key}: {value}")
    print(f"-------------------------------------------------------------\n\n")
# Out:
# ------------EVALUATING 'QUE PAIS E ESTE' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 8.2
# Acordes em Comum: {'C', 'Am', 'A', 'G', 'D', 'Em', 'B'}
# Acordes em Comum (%): 77.78
# Só na Cifra Gerada: {'E', 'F'}
# Só na Cifra Gerada (%): 22.22
# Só na Cifra de Validação: set()
# Só na Cifra de Validação (%): 0.0
# Acordes com Contagem:
#   C: (28, 30)
#   A: (2, 2)
#   Am: (1, 1)
#   F: (1, 0)
#   G: (3, 2)
#   D: (18, 32)
#   B: (2, 1)
#   E: (1, 0)
#   Em: (28, 31)
# Acordes com Contagem Igual (%): 22.22
# Posições dos Acordes:
#   posicoes_corretas: 8
#   posicoes_incorretas: 92
# Posições Iguais dos Acordes (%): 8.0
# Sequências:
#   sequências: [['Em', 'C', 'D', 'Em', 'C'], ['D'], ['Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Am', 'A', 'Em', 'C'], ['D'], ['Em', 'C', 'D'], ['Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C'], ['Em', 'C'], ['D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em'], ['D'], ['Em', 'C', 'D', 'Em']]
#   substituições: [{'cifra gerada': ['Em', 'C'], 'cifra validacao': ['G', 'G']}, {'cifra gerada': ['B'], 'cifra validacao': ['D', 'D', 'Em', 'C', 'D', 'A', 'Em', 'C']}]
#   exclusões: [['Em', 'C'], ['C'], ['B', 'F', 'Em', 'C', 'G', 'G', 'G', 'Em', 'C', 'E', 'Em', 'C', 'Em'], ['C', 'A', 'Em', 'C', 'Em', 'C'], ['C']]
#   inserções: [['D'], ['C'], ['C', 'D', 'Em', 'C', 'D', 'B', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em', 'C', 'D', 'Em']]
#   porcentagem_iguais: 50.0
#   porcentagem_diferentes: 50.0
# Sequências Iguais (%): 50.0
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'INFIEL' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 8.45
# Acordes em Comum: {'C', 'A', 'Am', 'D', 'E', 'Em'}
# Acordes em Comum (%): 75.0
# Só na Cifra Gerada: {'G', 'Am7'}
# Só na Cifra Gerada (%): 25.0
# Só na Cifra de Validação: set()
# Só na Cifra de Validação (%): 0.0
# Acordes com Contagem:
#   C: (7, 5)
#   A: (12, 9)
#   Am: (10, 12)
#   G: (3, 0)
#   D: (18, 17)
#   Am7: (2, 0)
#   E: (11, 9)
#   Em: (14, 13)
# Acordes com Contagem Igual (%): 0.0
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 155
# Posições Iguais dos Acordes (%): 1.27
# Sequências:
#   sequências: [['Em', 'C', 'D', 'Em', 'E'], ['D', 'D', 'Em', 'C', 'D', 'Em'], ['D', 'Am'], ['Em'], ['C'], ['D', 'E', 'Am'], ['E', 'Am'], ['C', 'Am', 'Em', 'E', 'D', 'E', 'A', 'A', 'Am', 'Em', 'A', 'D', 'D', 'A', 'E', 'Am7'], ['D', 'D', 'A', 'E']]
#   substituições: [{'cifra gerada': ['G'], 'cifra validacao': ['Am', 'Em', 'E']}, {'cifra gerada': ['Em', 'G', 'D'], 'cifra validacao': ['A', 'Am']}]
#   exclusões: [['Am', 'Em', 'D', 'A'], ['C'], ['C'], ['Em', 'D', 'A', 'Am', 'Em', 'G', 'D', 'E', 'Am', 'C', 'Am', 'Em', 'E', 'D', 'E', 'A', 'A', 'Am', 'Em', 'A'], ['Am7', 'Em', 'A', 'D', 'D', 'A', 'E']]
#   inserções: [['C'], ['Am', 'Em', 'E', 'E', 'D', 'Am', 'D'], ['D', 'D', 'A', 'A', 'Am', 'Am', 'Em', 'E', 'E', 'D', 'Am', 'D']]
#   porcentagem_iguais: 47.37
#   porcentagem_diferentes: 52.63
# Sequências Iguais (%): 47.37
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'TOCANDO EM FRENTE' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 6.59
# Acordes em Comum: {'E', 'C', 'D', 'A'}
# Acordes em Comum (%): 33.33
# Só na Cifra Gerada: {'Bb', 'Bb/2', 'F', 'Cm', 'Eb'}
# Só na Cifra Gerada (%): 41.67
# Só na Cifra de Validação: {'G', 'Dm', 'F9'}
# Só na Cifra de Validação (%): 25.0
# Acordes com Contagem:
#   C: (7, 20)
#   Bb: (14, 0)
#   Dm: (0, 12)
#   A: (2, 2)
#   Bb/2: (2, 0)
#   F: (12, 0)
#   Cm: (12, 0)
#   D: (2, 4)
#   G: (0, 12)
#   F9: (0, 23)
#   E: (15, 5)
#   Eb: (23, 0)
# Acordes com Contagem Igual (%): 8.33
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 236
# Posições Iguais dos Acordes (%): 0.84
# Sequências:
#   sequências: [['F', 'A'], ['E'], ['F'], ['D', 'F'], ['Cm', 'C'], ['E', 'Cm'], ['E']]
#   substituições: [{'cifra gerada': ['Eb'], 'cifra validacao': ['C', 'G', 'F9']}, {'cifra gerada': ['Bb', 'Bb/2'], 'cifra validacao': ['C', 'D', 'G', 'E']}, {'cifra gerada': ['Eb'], 'cifra validacao': ['C', 'Dm', 'C', 'F9', 'Dm', 'F9', 'Dm', 'F9', 'C', 'G', 'F9', 'C', 'G', 'C', 'F9', 'E', 'C', 'G', 'D', 'F9', 'Dm', 'F9', 'C', 'Dm', 'C', 'F9', 'Dm', 'F9', 'Dm', 'F9', 'C', 'G', 'F9', 'C', 'G', 'F9']}, {'cifra gerada': ['Eb'], 'cifra validacao': ['C', 'G', 'D', 'F9', 'Dm', 'F9', 'C', 'Dm', 'C', 'F9', 'Dm', 'F9', 'Dm', 'F9', 'C', 'G', 'F9', 'A', 'C', 'G', 'F9']}, {'cifra gerada': ['Bb', 'Eb'], 'cifra validacao': ['D', 'G']}]
#   exclusões: [['Eb', 'Bb'], ['Cm', 'Eb', 'Cm', 'Eb', 'Bb', 'Bb/2', 'F', 'Eb', 'C', 'Bb', 'E', 'F', 'C', 'Eb', 'E', 'Bb', 'F', 'E', 'Eb', 'Cm', 'C', 'Eb', 'E', 'Cm', 'E', 'Bb', 'Eb', 'Cm', 'Eb', 'Cm', 'Eb', 'Bb', 'F', 'Eb', 'Bb', 'F', 'E', 'Eb', 'C', 'Bb', 'E', 'F', 'Eb', 'D', 'Cm', 'C', 'Eb', 'E', 'Cm', 'Bb', 'E', 'Eb', 'Cm', 'Eb', 'Cm', 'Eb', 'Bb', 'F', 'A', 'Eb', 'E', 'Bb', 'F', 'Eb', 'C', 'Bb', 'E', 'F', 'E']]
#   inserções: [['G']]
#   porcentagem_iguais: 46.67
#   porcentagem_diferentes: 53.33
# Sequências Iguais (%): 46.67
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'PETROLINA JUAZEIRO' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 0.65
# Acordes em Comum: {'C', 'E7', 'Dm', 'Am', 'A', 'F', 'G7', 'D', 'E', 'B'}
# Acordes em Comum (%): 71.43
# Só na Cifra Gerada: {'D/3E', 'Bm7', 'G'}
# Só na Cifra Gerada (%): 21.43
# Só na Cifra de Validação: {'A7'}
# Só na Cifra de Validação (%): 7.14
# Acordes com Contagem:
#   Dm: (22, 22)
#   F: (4, 4)
#   G7: (1, 2)
#   D: (2, 2)
#   E: (40, 18)
#   D/3E: (1, 0)
#   C: (6, 8)
#   E7: (10, 32)
#   A7: (0, 12)
#   Am: (54, 48)
#   A: (4, 4)
#   G: (4, 0)
#   Bm7: (2, 0)
#   B: (4, 4)
# Acordes com Contagem Igual (%): 35.71
# Posições dos Acordes:
#   posicoes_corretas: 11
#   posicoes_incorretas: 199
# Posições Iguais dos Acordes (%): 5.24
# Sequências:
#   sequências: [['Am', 'E', 'Am'], ['Am', 'Dm', 'Am', 'E', 'Am', 'E', 'Am', 'D', 'E'], ['Am', 'Dm', 'Am', 'A', 'Dm', 'E', 'Am', 'C', 'B', 'Dm', 'Am'], ['A', 'Dm'], ['Am'], ['Dm', 'Am', 'E7', 'Am'], ['Am', 'Dm', 'G7', 'C', 'F'], ['E7', 'Am', 'E', 'E', 'Am', 'E', 'E', 'Am', 'E', 'Am', 'E'], ['Am', 'Dm'], ['E7'], ['Am', 'E7', 'Am'], ['Am', 'Dm', 'Am', 'E', 'Am', 'E', 'Am', 'D', 'E'], ['Am', 'Dm', 'Am', 'A', 'Dm', 'E', 'Am', 'C', 'B', 'Dm', 'Am'], ['A', 'Dm'], ['Am'], ['Dm', 'Am', 'E7', 'Am'], ['Am', 'Dm', 'G', 'C', 'F'], ['E', 'Am', 'E', 'E', 'Am', 'E'], ['Am', 'E']]
#   substituições: [{'cifra gerada': ['Bm7'], 'cifra validacao': ['Dm', 'E7', 'Am', 'E', 'E7', 'Am', 'E']}, {'cifra gerada': ['E'], 'cifra validacao': ['F', 'Am']}, {'cifra gerada': ['Bm7', 'E', 'Am', 'E', 'E7', 'E', 'Am', 'E', 'Am', 'E', 'E', 'Am', 'G'], 'cifra validacao': ['Dm']}, {'cifra gerada': ['G'], 'cifra validacao': ['E7']}]
#   exclusões: [['F', 'E', 'Am', 'E', 'Dm', 'Am', 'E'], ['E'], ['C', 'B'], ['E', 'Dm', 'Am', 'E7', 'Am', 'E', 'Dm', 'Am', 'E7'], ['Am', 'G'], ['Am', 'Dm'], ['D/3E', 'Am', 'E', 'Am', 'F', 'E', 'Am', 'E', 'Dm', 'Am', 'E'], ['E'], ['C', 'B'], ['E', 'Dm', 'Am', 'E7', 'Am', 'E', 'Dm', 'Am', 'E7']]
#   inserções: [['Am', 'E7', 'F', 'Am', 'A7', 'Dm', 'E7'], ['Am', 'A7', 'Dm', 'Am', 'A', 'Dm', 'E7', 'Am', 'C', 'B'], ['C', 'E7', 'Am', 'E'], ['Am', 'A7', 'Dm', 'Am', 'A', 'Dm', 'E7', 'Am', 'C', 'B'], ['C', 'E7', 'Am', 'E'], ['E7', 'Am', 'E', 'E7', 'Am', 'E', 'E7', 'Am', 'E', 'E7', 'Am', 'E', 'E7', 'Am', 'E', 'E7', 'Am', 'E']]
#   porcentagem_iguais: 48.72
#   porcentagem_diferentes: 51.28
# Sequências Iguais (%): 48.72
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'NAQUELA MESA' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 46.53
# Acordes em Comum: {'A7', 'Gm', 'Dm', 'A', 'E'}
# Acordes em Comum (%): 55.56
# Só na Cifra Gerada: {'Bb7', 'D', 'D7', 'Bdim'}
# Só na Cifra Gerada (%): 44.44
# Só na Cifra de Validação: set()
# Só na Cifra de Validação (%): 0.0
# Acordes com Contagem:
#   D7: (1, 0)
#   A7: (12, 4)
#   Gm: (13, 6)
#   Dm: (22, 9)
#   Bb7: (1, 0)
#   A: (5, 2)
#   D: (3, 0)
#   Bdim: (1, 0)
#   E: (16, 6)
# Acordes com Contagem Igual (%): 0.0
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 142
# Posições Iguais dos Acordes (%): 1.39
# Sequências:
#   sequências: [['Dm', 'A7', 'Dm', 'E'], ['A7', 'Dm', 'E', 'E', 'Gm', 'A', 'Dm', 'E', 'A'], ['D', 'Gm'], ['E'], ['A7', 'Dm', 'E'], ['Gm'], ['Dm', 'Gm', 'Dm']]
#   substituições: [{'cifra gerada': ['Dm'], 'cifra validacao': ['Gm']}]
#   exclusões: [['A7', 'Dm', 'Gm', 'E', 'A7', 'Dm', 'D7', 'Gm', 'E', 'Dm', 'E', 'A7', 'Dm', 'E', 'Gm', 'A7', 'Dm', 'E', 'A', 'D', 'Gm', 'E'], ['Gm', 'Dm', 'A', 'Dm', 'Gm', 'E', 'A7', 'Dm', 'A', 'D', 'Gm', 'E', 'Dm', 'A7', 'Dm', 'E', 'Gm', 'Dm'], ['Dm', 'A7'], ['A7', 'Dm', 'Gm', 'Bdim', 'Bb7', 'A7', 'Dm', 'E']]
#   inserções: [['Gm'], ['Dm'], ['A']]
#   porcentagem_iguais: 46.67
#   porcentagem_diferentes: 53.33
# Sequências Iguais (%): 46.67
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'UMA CARTA' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 27.04
# Acordes em Comum: {'C', 'A', 'F', 'G', 'E', 'B'}
# Acordes em Comum (%): 42.86
# Só na Cifra Gerada: {'Bb', 'Gm', 'C/5'}
# Só na Cifra Gerada (%): 21.43
# Só na Cifra de Validação: {'Fm', 'C7', 'D', 'C9', 'Bb9'}
# Só na Cifra de Validação (%): 35.71
# Acordes com Contagem:
#   C7: (0, 8)
#   F: (30, 14)
#   D: (0, 1)
#   C/5: (2, 0)
#   E: (8, 1)
#   C: (34, 4)
#   Gm: (1, 0)
#   Fm: (0, 6)
#   Bb: (13, 0)
#   A: (6, 2)
#   Bb9: (0, 5)
#   G: (4, 1)
#   C9: (0, 15)
#   B: (3, 1)
# Acordes com Contagem Igual (%): 0.0
# Posições dos Acordes:
#   posicoes_corretas: 7
#   posicoes_incorretas: 213
# Posições Iguais dos Acordes (%): 3.18
# Sequências:
#   sequências: [['C', 'C/5', 'F', 'C'], ['Bb', 'F'], ['C', 'Bb', 'F', 'C'], ['C', 'A', 'Bb', 'F', 'C', 'Bb', 'F'], ['A'], ['Bb', 'F', 'C', 'G', 'F', 'B', 'C'], ['F', 'C'], ['F', 'C'], ['F', 'C'], ['C', 'F']]
#   substituições: [{'cifra gerada': ['A'], 'cifra validacao': ['C7', 'C', 'F']}]
#   exclusões: [['C', 'G', 'F', 'C', 'G', 'F', 'C', 'C/5', 'G', 'F', 'C', 'E', 'F', 'C', 'E'], ['E', 'Bb', 'F', 'E'], ['C', 'Bb', 'F', 'C', 'Gm', 'B', 'F', 'C', 'F', 'C', 'C', 'F', 'C', 'F', 'C', 'C', 'F', 'C', 'E', 'Bb', 'F', 'C', 'E', 'Bb', 'F', 'C', 'Bb', 'F', 'C', 'E', 'Bb', 'F', 'E', 'A', 'C', 'Bb', 'F', 'C', 'Bb', 'F', 'A', 'C'], ['F', 'A'], ['C', 'F', 'C', 'B']]
#   inserções: [['C9', 'C7', 'C', 'F', 'Fm', 'C9', 'C7', 'F', 'Fm', 'C9', 'C7', 'C', 'F', 'Fm'], ['E'], ['D', 'C9'], ['C7', 'F'], ['C7', 'C', 'F']]
#   porcentagem_iguais: 47.62
#   porcentagem_diferentes: 52.38
# Sequências Iguais (%): 47.62
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'COMO VAI VOCE' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 6.29
# Acordes em Comum: {'Bm', 'C', 'E7', 'Dm', 'A', 'D', 'C#m', 'E', 'F#m'}
# Acordes em Comum (%): 45.0
# Só na Cifra Gerada: {'E/3', 'Esus4', 'D/3', 'E/2', 'Em'}
# Só na Cifra Gerada (%): 25.0
# Só na Cifra de Validação: {'E/G', 'A7', 'A/C', 'E4', 'Em7', 'F#m/E'}
# Só na Cifra de Validação (%): 30.0
# Acordes com Contagem:
#   Esus4: (1, 0)
#   Dm: (4, 2)
#   E4: (0, 2)
#   D: (8, 6)
#   E/2: (2, 0)
#   C#m: (4, 2)
#   E: (13, 8)
#   Em7: (0, 2)
#   Em: (4, 0)
#   E/G: (0, 6)
#   Bm: (4, 4)
#   C: (3, 4)
#   E7: (5, 6)
#   E/3: (1, 0)
#   A7: (0, 2)
#   D/3: (1, 0)
#   A: (14, 9)
#   A/C: (0, 4)
#   F#m: (12, 6)
#   F#m/E: (0, 4)
# Acordes com Contagem Igual (%): 5.0
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 188
# Posições Iguais dos Acordes (%): 1.05
# Sequências:
#   sequências: [['A'], ['F#m'], ['C'], ['Em', 'A', 'D', 'Dm', 'Esus4', 'E', 'E/2', 'A'], ['E7', 'F#m'], ['C#m'], ['Em', 'A', 'D', 'Dm', 'E', 'E7'], ['Em', 'A'], ['D'], ['E', 'E/2', 'A'], ['F#m', 'D/3'], ['F#m'], ['D'], ['E', 'Bm', 'E7'], ['E7', 'A', 'E']]
#   substituições: [{'cifra gerada': ['F#m', 'E', 'D', 'E', 'Bm'], 'cifra validacao': ['A']}, {'cifra gerada': ['E'], 'cifra validacao': ['C']}, {'cifra gerada': ['Dm'], 'cifra validacao': ['A/C', 'E', 'Bm']}, {'cifra gerada': ['E'], 'cifra validacao': ['F#m/E']}]
#   exclusões: [['C#m', 'E', 'Em', 'A', 'D', 'Dm', 'E', 'A', 'A', 'F#m', 'C', 'C#m'], ['A', 'F#m', 'E', 'D', 'Bm', 'E7', 'F#m', 'E/3', 'A', 'F#m'], ['A', 'F#m', 'C', 'C#m'], ['F#m', 'A', 'F#m', 'E', 'D', 'Bm']]
#   inserções: [['E/G'], ['C#m'], ['E/G', 'F#m', 'F#m/E'], ['E/G', 'F#m'], ['A/C', 'Bm', 'E7', 'E', 'A', 'C', 'A', 'E/G'], ['A/C'], ['F#m', 'F#m/E', 'D', 'A/C', 'Bm', 'E7', 'E', 'A', 'C']]
#   porcentagem_iguais: 50.0
#   porcentagem_diferentes: 50.0
# Sequências Iguais (%): 50.0
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'EVIDENCIAS' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 28.18
# Acordes em Comum: {'C', 'E7', 'A', 'B7', 'F', 'C#7', 'D', 'C#m', 'E', 'F#m', 'B'}
# Acordes em Comum (%): 32.35
# Só na Cifra Gerada: {'E/3', 'Ab7', 'F#m7', 'B/3', 'E/5', 'Caug', 'A/5', 'Am', 'Cdim', 'Eaug', 'C#/5', 'F#7'}
# Só na Cifra Gerada (%): 35.29
# Só na Cifra de Validação: {'C#m7', 'E/G', 'E6', 'B/D', 'A/C', 'E4', 'G#', 'F#/A', 'A/B', 'F#', 'E5'}
# Só na Cifra de Validação (%): 32.35
# Acordes com Contagem:
#   C#m7: (0, 1)
#   G#: (0, 4)
#   D: (4, 13)
#   Eaug: (1, 0)
#   E: (17, 30)
#   E5: (0, 5)
#   F#7: (2, 0)
#   E/G: (0, 6)
#   C: (7, 6)
#   E7: (2, 6)
#   E6: (0, 3)
#   B/D: (0, 4)
#   B/3: (2, 0)
#   E/5: (1, 0)
#   A: (7, 12)
#   Am: (1, 0)
#   A/C: (0, 1)
#   Cdim: (2, 0)
#   C#/5: (1, 0)
#   F#m: (4, 16)
#   Ab7: (2, 0)
#   Caug: (1, 0)
#   E4: (0, 4)
#   F: (1, 2)
#   F#/A: (0, 1)
#   C#m: (5, 2)
#   F#: (0, 1)
#   E/3: (2, 0)
#   F#m7: (4, 0)
#   A/5: (1, 0)
#   B7: (8, 16)
#   C#7: (1, 3)
#   A/B: (0, 4)
#   B: (3, 1)
# Acordes com Contagem Igual (%): 0.0
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 285
# Posições Iguais dos Acordes (%): 0.7
# Sequências:
#   sequências: [['E', 'B/3', 'C#m', 'E7'], ['A'], ['C', 'C'], ['F#m', 'B7', 'Cdim', 'E'], ['Am', 'E', 'E/5'], ['E', 'A/5'], ['D', 'A', 'F#m7', 'B7', 'F#m7', 'B7', 'E', 'E', 'C', 'D'], ['E', 'E', 'A', 'E', 'F#m7', 'B7'], ['F#m7', 'B7', 'E', 'Eaug'], ['A'], ['D', 'F#m', 'B', 'E'], ['A', 'E/3'], ['F#m', 'B']]
#   substituições: [{'cifra gerada': ['C', 'C', 'C', 'C'], 'cifra validacao': ['F#', 'E/G', 'F#/A', 'B', 'A/C', 'B/D', 'E', 'E', 'B/D', 'D', 'C#m', 'E7', 'E6', 'E7', 'A', 'F', 'C#7', 'E']}, {'cifra gerada': ['B7'], 'cifra validacao': ['E', 'E4']}, {'cifra gerada': ['E', 'E', 'Ab7'], 'cifra validacao': ['G#']}, {'cifra gerada': ['Ab7'], 'cifra validacao': ['G#']}, {'cifra gerada': ['C#m', 'Caug'], 'cifra validacao': ['E5', 'D', 'A', 'E/G', 'F#m', 'B7', 'E', 'E5', 'D', 'A', 'E/G', 'F#m', 'B7', 'E']}]
#   exclusões: [['A'], ['C#m', 'E', 'E', 'F#7', 'E/3', 'F#7', 'B', 'B7', 'E', 'B/3', 'E', 'C#m', 'E7', 'A', 'C#/5', 'C#7', 'F', 'F#m', 'B7', 'Cdim', 'C#m'], ['D']]
#   inserções: [['E6', 'E7'], ['C#7', 'F#m', 'B7', 'E'], ['D'], ['D'], ['E/G', 'F#m', 'B7', 'E5', 'D', 'A', 'E/G', 'F#m', 'B7', 'E', 'E', 'B/D', 'D', 'C#m', 'E7', 'E6', 'E7', 'A', 'F', 'C#7', 'E', 'F#m', 'B7', 'C', 'E', 'A/B', 'E', 'E4', 'E', 'E4', 'E', 'A/B', 'G#', 'D', 'A', 'F#m', 'B7', 'F#m', 'B7', 'E', 'E', 'C', 'D', 'G#', 'E', 'E', 'A', 'E', 'F#m', 'B7'], ['E5', 'D']]
#   porcentagem_iguais: 48.15
#   porcentagem_diferentes: 51.85
# Sequências Iguais (%): 48.15
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'SOZINHO' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 1.96
# Acordes em Comum: {'Bm', 'C', 'A7', 'F#m7', 'F', 'G7', 'D', 'G', 'E', 'Em'}
# Acordes em Comum (%): 34.48
# Só na Cifra Gerada: {'C#m7', 'Bm/b7', 'A/3', 'A/b7A7Bm', 'G/2', 'A', 'C#7', 'D/2', 'Bm7', 'Em7', 'F#m'}
# Só na Cifra Gerada (%): 37.93
# Só na Cifra de Validação: {'B2', 'Em/D', 'C/G', 'B7', 'A7/C', 'D6', 'G/A', 'Bm7/E'}
# Só na Cifra de Validação (%): 27.59
# Acordes com Contagem:
#   C#m7: (5, 0)
#   A/3: (3, 0)
#   A/b7A7Bm: (1, 0)
#   C/G: (0, 2)
#   D: (7, 2)
#   G/A: (0, 2)
#   E: (5, 3)
#   Bm: (11, 11)
#   C: (2, 2)
#   A7: (4, 5)
#   Em/D: (0, 6)
#   A: (5, 0)
#   G: (9, 2)
#   F#m: (3, 0)
#   B2: (0, 5)
#   F: (2, 2)
#   G7: (4, 4)
#   D6: (0, 7)
#   Em7: (1, 0)
#   Em: (6, 6)
#   F#m7: (5, 3)
#   Bm/b7: (1, 0)
#   Bm7/E: (0, 1)
#   G/2: (1, 0)
#   B7: (0, 1)
#   C#7: (1, 0)
#   A7/C: (0, 11)
#   D/2: (1, 0)
#   Bm7: (1, 0)
# Acordes com Contagem Igual (%): 17.24
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 198
# Posições Iguais dos Acordes (%): 1.0
# Sequências:
#   sequências: [['A/3', 'Bm'], ['Em'], ['A7'], ['D'], ['E', 'A', 'Bm'], ['F#m', 'G7', 'Bm', 'F#m7'], ['Bm', 'F#m7', 'G'], ['A', 'Bm'], ['Em'], ['A7', 'D', 'A'], ['Em', 'E'], ['Em'], ['A/3'], ['A', 'D', 'A/3', 'G', 'Em', 'F'], ['C', 'D'], ['Bm7', 'G', 'G/2'], ['A']]
#   substituições: [{'cifra gerada': ['Bm/b7'], 'cifra validacao': ['D6']}, {'cifra gerada': ['G', 'C#7', 'C#m7'], 'cifra validacao': ['Em/D']}, {'cifra gerada': ['D/2'], 'cifra validacao': ['Bm7/E']}, {'cifra gerada': ['G', 'C#m7', 'C#m7'], 'cifra validacao': ['Em/D', 'A7/C']}, {'cifra gerada': ['G'], 'cifra validacao': ['Em/D', 'C']}, {'cifra gerada': ['F#m', 'Bm'], 'cifra validacao': ['A7/C']}]
#   exclusões: [['E', 'Em7', 'C#m7', 'A7', 'Bm', 'A7'], ['Bm'], ['C#m7', 'A/b7A7Bm', 'F#m7', 'G7', 'Bm', 'F#m7'], ['Bm', 'E', 'F#m7', 'G7', 'E', 'D'], ['G7', 'Em', 'F', 'G', 'C', 'D', 'F#m', 'Bm', 'G', 'D', 'G']]
#   inserções: [['Bm', 'B2', 'Bm'], ['A7', 'E'], ['A7/C', 'B2', 'Bm', 'E', 'B7', 'Bm', 'Em'], ['D6'], ['Bm', 'B2', 'Bm'], ['D6'], ['D6', 'A7/C', 'G7', 'Em', 'F', 'Em/D', 'C', 'C/G', 'D', 'A7/C', 'Bm', 'G', 'G/A']]
#   porcentagem_iguais: 48.57
#   porcentagem_diferentes: 51.43
# Sequências Iguais (%): 48.57
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'GAROTA DE IPANEMA' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 45.79
# Acordes em Comum: {'F7', 'D7', 'F#m7', 'A', 'Gm7', 'C7', 'G7', 'B7', 'Am7', 'Eb7', 'F#7'}
# Acordes em Comum (%): 42.31
# Só na Cifra Gerada: {'B9', 'E7', 'A7', 'Ab7', 'Fm7', 'Bb7', 'Eb/2', 'Eb9', 'F', 'C#7', 'D', 'Bbm7', 'E/2', 'E', 'Bb9'}
# Só na Cifra Gerada (%): 57.69
# Só na Cifra de Validação: set()
# Só na Cifra de Validação (%): 0.0
# Acordes com Contagem:
#   D7: (6, 1)
#   Ab7: (2, 0)
#   Fm7: (2, 0)
#   Bb7: (1, 0)
#   Eb9: (1, 0)
#   C7: (4, 5)
#   F: (1, 0)
#   G7: (6, 3)
#   D: (1, 0)
#   E/2: (1, 0)
#   Am7: (1, 1)
#   E: (2, 0)
#   Eb7: (1, 1)
#   F#7: (9, 1)
#   B9: (1, 0)
#   F7: (14, 6)
#   E7: (1, 0)
#   A7: (1, 0)
#   F#m7: (1, 1)
#   Eb/2: (1, 0)
#   A: (10, 4)
#   Gm7: (6, 5)
#   B7: (1, 1)
#   C#7: (2, 0)
#   Bbm7: (1, 0)
#   Bb9: (1, 0)
# Acordes com Contagem Igual (%): 15.38
# Posições dos Acordes:
#   posicoes_corretas: 1
#   posicoes_incorretas: 175
# Posições Iguais dos Acordes (%): 0.57
# Sequências:
#   sequências: [['C7', 'F7', 'G7'], ['Am7'], ['Gm7', 'C7', 'F7'], ['C7', 'F7']]
#   substituições: []
#   exclusões: [['Gm7', 'F#7', 'F7', 'F#7', 'F7', 'G7', 'Gm7', 'F#7', 'F7', 'F#7', 'B9', 'F#m7', 'D7', 'Gm7', 'Eb7'], ['D7'], ['A', 'G7', 'A', 'Gm7', 'A', 'F#7', 'F7', 'F#7', 'A', 'F7', 'F#7', 'F7', 'D7', 'D', 'A', 'D7', 'G7', 'E7', 'F7', 'F', 'Eb/2', 'E', 'Bb7', 'B7', 'D7', 'A', 'G7', 'F7', 'D7', 'A', 'Fm7', 'Bbm7', 'C7', 'A', 'Fm7', 'Bb9', 'Eb9', 'A7', 'Ab7', 'C#7', 'A', 'Ab7', 'C#7', 'F7', 'A', 'G7', 'Gm7', 'F#7', 'F7', 'F#7', 'E', 'F7', 'E/2']]
#   inserções: [['F7', 'G7', 'Gm7', 'C7', 'Am7', 'F7', 'G7', 'Gm7', 'C7', 'F7', 'F#7', 'B7', 'A', 'F#m7', 'D7', 'A', 'Gm7', 'Eb7', 'A', 'Gm7']]
#   porcentagem_iguais: 50.0
#   porcentagem_diferentes: 50.0
# Sequências Iguais (%): 50.0
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'JOAO E MARIA' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 12.42
# Acordes em Comum: {'Am', 'A', 'F', 'G', 'E'}
# Acordes em Comum (%): 13.51
# Só na Cifra Gerada: {'F/3', 'Ab', 'Gm', 'Bb', 'Dm', 'Bb/5', 'Bb/2', 'Cm', 'D', 'Eb'}
# Só na Cifra Gerada (%): 27.03
# Só na Cifra de Validação: {'Bb7', 'Dm7', 'E/G', 'C', 'F7', 'E7', 'A7', 'E7/B', 'Dm/F', 'Am7/G', 'G/B', 'G7', 'A/G', 'Am7', 'Em', 'Bm7', 'F#m7', 'B7', 'A7/C', 'Gm6/Bb', 'Am9', 'B7/F'}
# Só na Cifra de Validação (%): 59.46
# Acordes com Contagem:
#   Bb7: (0, 2)
#   Bb/5: (1, 0)
#   Dm7: (0, 6)
#   D: (3, 0)
#   E: (20, 8)
#   E/G: (0, 1)
#   F/3: (1, 0)
#   C: (0, 8)
#   Gm: (11, 0)
#   F7: (0, 2)
#   E7: (0, 4)
#   A7: (0, 1)
#   E7/B: (0, 2)
#   A: (9, 4)
#   Am: (1, 4)
#   Bb/2: (1, 0)
#   Cm: (9, 0)
#   G: (2, 1)
#   Dm/F: (0, 1)
#   Am7/G: (0, 1)
#   G/B: (0, 1)
#   Dm: (1, 0)
#   F: (5, 2)
#   G7: (0, 3)
#   A/G: (0, 1)
#   Am7: (0, 1)
#   Eb: (8, 0)
#   Em: (0, 1)
#   Ab: (5, 0)
#   Bm7: (0, 5)
#   F#m7: (0, 1)
#   Bb: (9, 0)
#   B7: (0, 1)
#   A7/C: (0, 1)
#   Gm6/Bb: (0, 1)
#   Am9: (0, 3)
#   B7/F: (0, 1)
# Acordes com Contagem Igual (%): 0.0
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 196
# Posições Iguais dos Acordes (%): 1.01
# Sequências:
#   sequências: [['Gm'], ['Gm'], ['A'], ['Cm'], ['Gm', 'E', 'Cm'], ['A', 'F'], ['Bb', 'E', 'A', 'E', 'Dm'], ['Cm', 'A', 'A'], ['Gm', 'E'], ['Cm', 'E'], ['Bb', 'E'], ['F']]
#   substituições: [{'cifra gerada': ['Eb'], 'cifra validacao': ['C', 'E', 'B7', 'E', 'B7/F', 'Em', 'C']}, {'cifra gerada': ['Eb', 'Gm'], 'cifra validacao': ['F7', 'E7']}, {'cifra gerada': ['Bb/2', 'Bb'], 'cifra validacao': ['Am', 'E']}, {'cifra gerada': ['Bb', 'G', 'Eb', 'E', 'Gm'], 'cifra validacao': ['Bm7']}, {'cifra gerada': ['Bb'], 'cifra validacao': ['F#m7', 'A', 'F7', 'E7', 'Am9', 'Dm7', 'A', 'Bm7', 'C', 'Am', 'Dm7', 'Bm7']}, {'cifra gerada': ['Eb', 'E', 'Ab', 'D', 'Gm', 'Eb'], 'cifra validacao': ['Am9']}]
#   exclusões: [['Am', 'Ab', 'G', 'A', 'E', 'Cm', 'F'], ['Bb', 'E', 'Ab', 'D', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'Cm', 'A', 'Bb', 'Bb/5', 'Eb', 'Gm', 'A', 'Cm', 'A', 'Bb', 'Gm', 'Cm', 'F/3', 'Ab', 'Gm', 'E', 'Cm', 'F', 'Bb', 'Eb', 'Ab', 'E', 'Eb', 'D', 'Gm', 'F']]
#   inserções: [['Dm7', 'A'], ['Dm7', 'A', 'Bm7'], ['E7', 'Am9', 'E/G'], ['Dm/F', 'E', 'Bm7', 'C', 'E'], ['A7', 'G/B', 'A7/C', 'Dm7', 'G7']]
#   porcentagem_iguais: 48.0
#   porcentagem_diferentes: 52.0
# Sequências Iguais (%): 48.0
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'AGUAS DE MARCO' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 19.27
# Acordes em Comum: {'C', 'E7', 'F7', 'A', 'B7', 'D', 'E', 'Bm7', 'B'}
# Acordes em Comum (%): 32.14
# Só na Cifra Gerada: {'D7', 'Em/5', 'Fm7', 'Abm7', 'Em/b3', 'A/5', 'F#7', 'Em7', 'Em'}
# Só na Cifra Gerada (%): 32.14
# Só na Cifra de Validação: {'B6', 'B/A', 'F#m7', 'D#/B', 'F', 'F#', 'Em6', 'C/B', 'G#m6', 'Em6/G'}
# Só na Cifra de Validação (%): 35.71
# Acordes com Contagem:
#   B6: (0, 28)
#   D7: (1, 0)
#   Abm7: (2, 0)
#   Fm7: (14, 0)
#   Em/b3: (2, 0)
#   F: (0, 15)
#   D: (1, 1)
#   Em6: (0, 15)
#   E: (2, 1)
#   F#: (0, 5)
#   Em7: (14, 0)
#   Em: (5, 0)
#   F#7: (2, 0)
#   C: (1, 1)
#   F7: (3, 1)
#   E7: (3, 1)
#   Em/5: (2, 0)
#   B/A: (0, 5)
#   F#m7: (0, 12)
#   A/5: (1, 0)
#   D#/B: (0, 2)
#   A: (1, 3)
#   B7: (20, 22)
#   Em6/G: (0, 6)
#   C/B: (0, 2)
#   G#m6: (0, 6)
#   Bm7: (2, 2)
#   B: (12, 2)
# Acordes com Contagem Igual (%): 10.71
# Posições dos Acordes:
#   posicoes_corretas: 5
#   posicoes_incorretas: 241
# Posições Iguais dos Acordes (%): 2.03
# Sequências:
#   sequências: [['B7'], ['F#7', 'F7', 'E7'], ['B7', 'Fm7', 'Em7', 'B7', 'C'], ['B'], ['B7', 'Fm7', 'Em7', 'B'], ['B7'], ['B7', 'Fm7', 'Em7', 'B7'], ['Fm7', 'Em7', 'B'], ['B', 'B7', 'Fm7', 'Em7', 'B', 'B7'], ['E7'], ['B', 'B7', 'Fm7', 'Em7', 'B7'], ['F#7'], ['B', 'B7', 'Fm7', 'Em7', 'B7'], ['B', 'B7', 'Fm7', 'Em7', 'B7'], ['Fm7', 'Em7', 'B', 'Bm7'], ['B7', 'Fm7', 'Em7', 'B7'], ['B7'], ['Fm7', 'Em', 'B']]
#   substituições: [{'cifra gerada': ['Fm7', 'Em7'], 'cifra validacao': ['F#m7']}, {'cifra gerada': ['Em'], 'cifra validacao': ['F#m7']}, {'cifra gerada': ['A/5'], 'cifra validacao': ['B7', 'F#', 'F#m7']}, {'cifra gerada': ['Fm7', 'Em7'], 'cifra validacao': ['F#m7']}, {'cifra gerada': ['A'], 'cifra validacao': ['B7', 'B6', 'F']}]
#   exclusões: [['Abm7', 'Em/b3'], ['Em', 'B', 'Em', 'B7', 'D', 'Fm7', 'Em7'], ['Em7'], ['F7', 'D7', 'B7', 'Abm7', 'Em/b3'], ['F7', 'E', 'Em'], ['Em/5', 'B', 'Bm7', 'Em/5'], ['E', 'E7']]
#   inserções: [['G#m6', 'Em6/G'], ['Em6', 'B7', 'F#m7', 'B7'], ['F#m7'], ['F#m7', 'B7', 'B6', 'F', 'Em6', 'D', 'B7', 'B/A', 'G#m6', 'Em6/G', 'B6', 'F#m7', 'B7', 'B6'], ['G#m6'], ['B/A', 'G#m6', 'Em6/G', 'B7', 'F#', 'F#m7', 'B7', 'B6'], ['B/A', 'G#m6', 'Em6/G', 'B7', 'F#', 'Bm7', 'D#/B', 'C/B', 'B', 'Bm7', 'D#/B', 'C/B', 'B', 'B/A', 'G#m6', 'A', 'Em6/G', 'B7', 'F#', 'E', 'F#m7', 'B7', 'B6', 'F', 'Em6', 'A', 'B6', 'A', 'F#m7', 'B7', 'B6', 'F', 'Em6', 'B6']]
#   porcentagem_iguais: 48.65
#   porcentagem_diferentes: 51.35
# Sequências Iguais (%): 48.65
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'CORCOVADO' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 15.25
# Acordes em Comum: {'C', 'F7', 'A7', 'Fm7', 'A', 'Dm7', 'C7', 'Gm7', 'G7', 'D', 'Am7', 'E', 'Em7', 'F#7'}
# Acordes em Comum (%): 42.42
# Só na Cifra Gerada: {'E/3', 'E7', 'D7', 'Ab7', 'D9', 'Abm7', 'Am', 'C#7', 'G', 'Eb7'}
# Só na Cifra Gerada (%): 30.3
# Só na Cifra de Validação: {'E6', 'C#', 'Fm6', 'G#', 'E9', 'Am6', 'Cm6', 'G#m6', 'Gm6'}
# Só na Cifra de Validação (%): 27.27
# Acordes com Contagem:
#   D7: (4, 0)
#   C#: (0, 1)
#   Fm6: (0, 1)
#   Abm7: (3, 0)
#   Fm7: (3, 1)
#   Dm7: (3, 7)
#   C7: (3, 1)
#   G#: (0, 2)
#   D: (4, 3)
#   E: (4, 2)
#   F#7: (3, 1)
#   Gm6: (0, 2)
#   C: (2, 1)
#   F7: (4, 1)
#   E7: (1, 0)
#   A7: (2, 1)
#   E6: (0, 3)
#   Am: (1, 0)
#   A: (3, 3)
#   Gm7: (3, 2)
#   E9: (0, 2)
#   G: (1, 0)
#   Cm6: (0, 1)
#   Ab7: (2, 0)
#   D9: (1, 0)
#   G7: (5, 4)
#   Am6: (0, 4)
#   Am7: (5, 2)
#   Eb7: (1, 0)
#   Em7: (6, 4)
#   E/3: (1, 0)
#   C#7: (3, 0)
#   G#m6: (0, 1)
# Acordes com Contagem Igual (%): 3.03
# Posições dos Acordes:
#   posicoes_corretas: 1
#   posicoes_incorretas: 178
# Posições Iguais dos Acordes (%): 0.56
# Sequências:
#   sequências: [['Am', 'E/3'], ['E', 'Gm7', 'C7'], ['F7', 'Fm7'], ['E7'], ['C', 'G7'], ['Gm7'], ['F#7'], ['Fm7', 'A', 'Em7', 'E', 'Am7', 'Dm7', 'D', 'G7'], ['Em7', 'Am7'], ['Dm7', 'G7'], ['C7'], ['Em7', 'E', 'Am7', 'Dm7', 'D', 'G7', 'Em7', 'A7'], ['A']]
#   substituições: [{'cifra gerada': ['F#7'], 'cifra validacao': ['Gm6']}, {'cifra gerada': ['A7', 'D7', 'E', 'G7', 'D'], 'cifra validacao': ['G#']}, {'cifra gerada': ['A'], 'cifra validacao': ['C#', 'E']}, {'cifra gerada': ['D', 'G', 'D7', 'C#7', 'D9'], 'cifra validacao': ['Am6', 'G#m6']}]
#   exclusões: [['Em7', 'Am7', 'D7', 'Abm7'], ['Am7', 'Abm7', 'C'], ['C7'], ['F7'], ['F7', 'Em7', 'Eb7', 'Ab7', 'Ab7', 'Abm7', 'C#7', 'D7', 'C#7', 'Gm7'], ['F#7', 'F7', 'Fm7']]
#   inserções: [['G#'], ['Dm7', 'D', 'Dm7', 'Am6'], ['A', 'G7', 'E6'], ['Dm7', 'Dm7']]
#   porcentagem_iguais: 48.15
#   porcentagem_diferentes: 51.85
# Sequências Iguais (%): 48.15
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'SUMMERTIME SADNESS' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 0.0
# Acordes em Comum: {'C', 'A', 'G', 'D', 'C#m', 'E', 'F#m', 'B'}
# Acordes em Comum (%): 66.67
# Só na Cifra Gerada: {'Abm', 'F#', 'Bsus4'}
# Só na Cifra Gerada (%): 25.0
# Só na Cifra de Validação: {'G#m'}
# Só na Cifra de Validação (%): 8.33
# Acordes com Contagem:
#   G#m: (0, 2)
#   Abm: (4, 0)
#   D: (3, 2)
#   C#m: (26, 26)
#   E: (1, 1)
#   F#: (1, 0)
#   C: (1, 1)
#   A: (25, 26)
#   G: (7, 8)
#   Bsus4: (1, 0)
#   F#m: (24, 25)
#   B: (24, 26)
# Acordes com Contagem Igual (%): 25.0
# Posições dos Acordes:
#   posicoes_corretas: 5
#   posicoes_incorretas: 144
# Posições Iguais dos Acordes (%): 3.36
# Sequências:
#   sequências: [['F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m'], ['A', 'C#m'], ['B', 'F#m', 'A', 'C#m', 'G', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A'], ['C#m'], ['B', 'F#m'], ['A', 'C#m'], ['B', 'F#m', 'A'], ['C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A'], ['G'], ['C#m', 'B', 'F#m']]
#   substituições: [{'cifra gerada': ['D'], 'cifra validacao': ['A', 'G', 'C#m', 'B', 'F#m']}, {'cifra gerada': ['D'], 'cifra validacao': ['B', 'C', 'F#m', 'G', 'A', 'C#m', 'G']}, {'cifra gerada': ['C'], 'cifra validacao': ['G#m', 'C#m', 'A', 'F#m', 'G#m', 'C#m', 'B', 'E']}]
#   exclusões: [['G'], ['G', 'B', 'A', 'C#m', 'G'], ['C#m'], ['B', 'F#m', 'Abm', 'C#m', 'A', 'F#m', 'Abm', 'C#m', 'B', 'Bsus4', 'E', 'D', 'A'], ['A', 'C#m', 'G', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'G', 'B', 'F#m', 'Abm', 'C#m', 'A', 'F#', 'Abm']]
#   inserções: [['A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'F#m', 'A', 'C#m', 'B', 'D', 'F#m', 'A', 'D', 'C#m', 'B', 'B', 'F#m', 'A', 'C#m', 'G', 'B', 'F#m', 'A', 'A', 'C#m', 'B'], ['G'], ['G']]
#   porcentagem_iguais: 47.62
#   porcentagem_diferentes: 52.38
# Sequências Iguais (%): 47.62
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'BEAUTIFUL THINGS' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 0.47
# Acordes em Comum: {'Gm', 'Bb', 'A', 'F', 'G', 'D', 'Cm', 'Eb', 'B'}
# Acordes em Comum (%): 81.82
# Só na Cifra Gerada: {'D/3'}
# Só na Cifra Gerada (%): 9.09
# Só na Cifra de Validação: {'F#'}
# Só na Cifra de Validação (%): 9.09
# Acordes com Contagem:
#   F: (27, 26)
#   D: (4, 4)
#   F#: (0, 2)
#   Eb: (23, 23)
#   Gm: (14, 14)
#   D/3: (1, 0)
#   Bb: (23, 22)
#   A: (6, 5)
#   G: (5, 5)
#   Cm: (1, 1)
#   B: (4, 5)
# Acordes com Contagem Igual (%): 45.45
# Posições dos Acordes:
#   posicoes_corretas: 7
#   posicoes_incorretas: 125
# Posições Iguais dos Acordes (%): 5.3
# Sequências:
#   sequências: [['Eb', 'Bb', 'F', 'F', 'Gm', 'B', 'Eb', 'Bb', 'D', 'F', 'Eb', 'Bb', 'A', 'F', 'Gm', 'Eb', 'Bb', 'F', 'A', 'Eb', 'Bb', 'A', 'G', 'F'], ['Gm', 'F', 'Eb', 'Bb', 'B', 'F', 'Eb', 'Bb', 'A', 'Gm'], ['F', 'Eb'], ['Cm', 'B', 'F'], ['F', 'Gm', 'Eb', 'Bb', 'F', 'Gm', 'Eb', 'G', 'Bb', 'F', 'D', 'Eb', 'Bb', 'Gm', 'F', 'Eb'], ['Bb'], ['Gm', 'D', 'F', 'Eb', 'Bb', 'Gm', 'F', 'Eb', 'Bb', 'F', 'Eb', 'Bb', 'F', 'Gm'], ['Eb', 'Bb', 'F', 'Eb', 'Bb', 'F'], ['Gm', 'Eb'], ['Bb', 'F', 'Eb'], ['Bb', 'Gm', 'F', 'Eb', 'G', 'Bb', 'Gm', 'D', 'F', 'Eb', 'Bb', 'Gm', 'F', 'Eb', 'Bb', 'F', 'Eb', 'G', 'Bb', 'F']]
#   substituições: [{'cifra gerada': ['D/3'], 'cifra validacao': ['F#']}]
#   exclusões: [['F'], ['A'], ['Bb', 'A'], ['G'], ['B']]
#   inserções: [['F#'], ['A'], ['G'], ['B'], ['B']]
#   porcentagem_iguais: 50.0
#   porcentagem_diferentes: 50.0
# Sequências Iguais (%): 50.0
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'IT S MY LIFE' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 12.26
# Acordes em Comum: {'Bb', 'F', 'G', 'D', 'B'}
# Acordes em Comum (%): 23.81
# Só na Cifra Gerada: {'Ab/3', 'Ab', 'C', 'Cm', 'G/3', 'Bdim', 'Eb'}
# Só na Cifra Gerada (%): 33.33
# Só na Cifra de Validação: {'C5/G', 'Bb/D', 'Eb5', 'F5/C', 'F5', 'B5', 'Ab5', 'Bb5', 'C5'}
# Só na Cifra de Validação (%): 42.86
# Acordes com Contagem:
#   Ab/3: (1, 0)
#   C5: (0, 16)
#   Bb/D: (0, 8)
#   Eb5: (0, 8)
#   F5/C: (0, 2)
#   F: (7, 5)
#   D: (1, 1)
#   Ab5: (0, 18)
#   Eb: (9, 0)
#   Ab: (18, 0)
#   C: (1, 0)
#   Bb: (12, 7)
#   F5: (0, 1)
#   Cm: (21, 0)
#   G: (1, 2)
#   B5: (0, 1)
#   G/3: (2, 0)
#   Bdim: (5, 0)
#   C5/G: (0, 6)
#   Bb5: (0, 10)
#   B: (41, 8)
# Acordes com Contagem Igual (%): 4.76
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 292
# Posições Iguais dos Acordes (%): 0.68
# Sequências:
#   sequências: [['Cm', 'Cm'], ['F', 'Cm', 'Ab', 'Eb', 'Bb', 'Cm', 'Ab', 'Bb'], ['G/3', 'Cm', 'Ab', 'Eb'], ['Cm', 'Ab'], ['Bb', 'Bdim', 'Ab', 'Bb'], ['F', 'Cm', 'B', 'D', 'Cm', 'Ab', 'Eb', 'Bb', 'Cm', 'Ab', 'Bb'], ['Bb', 'Bdim', 'Cm', 'Ab', 'Eb'], ['Cm', 'Ab'], ['Bb', 'Bdim', 'Cm', 'Ab', 'Eb'], ['B', 'Cm'], ['F'], ['Ab', 'Bb']]
#   substituições: [{'cifra gerada': ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'F'], 'cifra validacao': ['Bb/D']}, {'cifra gerada': ['C', 'Cm'], 'cifra validacao': ['Ab5']}, {'cifra gerada': ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B'], 'cifra validacao': ['F', 'Bb/D']}, {'cifra gerada': ['B', 'B', 'B', 'B', 'B', 'B', 'B'], 'cifra validacao': ['Bb/D', 'C5', 'Ab5', 'Bb5', 'Bb']}]
#   exclusões: [['Ab/3', 'Eb'], ['Ab', 'Eb', 'Bb', 'Cm', 'Ab', 'Bb', 'G/3', 'Cm', 'Ab', 'Eb', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'Cm', 'F', 'Ab', 'Bb', 'Bdim', 'Cm', 'Ab', 'Cm', 'F', 'G'], ['Bdim', 'Cm', 'Ab', 'Eb', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'Cm', 'F', 'Ab']]
#   inserções: [['Bb', 'B', 'C5', 'Ab5', 'Eb5', 'F', 'Bb/D', 'C5', 'Ab5', 'Bb5', 'Bb', 'B', 'C5/G', 'C5/G', 'F', 'G', 'C5/G', 'F5/C'], ['Bb5', 'Bb', 'B', 'C5', 'Ab5', 'Eb5', 'F', 'Bb/D', 'C5', 'Ab5', 'Bb5'], ['Bb5'], ['Ab5', 'Eb5'], ['Bb/D', 'C5'], ['Bb5', 'B5']]
#   porcentagem_iguais: 48.0
#   porcentagem_diferentes: 52.0
# Sequências Iguais (%): 48.0
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'ALWAYS ON MY MIND' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 23.75
# Acordes em Comum: {'C', 'D7', 'G/B', 'A', 'G', 'D', 'Am7', 'Em'}
# Acordes em Comum (%): 34.78
# Só na Cifra Gerada: {'A/3A', 'D/3', 'A/3', 'Am', 'G/3C', 'G/5CG', 'G/5', 'Em/b7'}
# Só na Cifra Gerada (%): 34.78
# Só na Cifra de Validação: {'Em/D', 'F/A', 'Am/G', 'Am/E', 'D/F', 'A7/C', 'C/E'}
# Só na Cifra de Validação (%): 30.43
# Acordes com Contagem:
#   D7: (2, 2)
#   A/3A: (1, 0)
#   G/B: (99, 11)
#   A/3: (1, 0)
#   D: (16, 14)
#   Am/E: (0, 3)
#   G/5CG: (1, 0)
#   Am7: (1, 5)
#   D/F: (0, 13)
#   Em: (11, 10)
#   C: (17, 18)
#   Em/D: (0, 10)
#   D/3: (11, 0)
#   F/A: (0, 3)
#   C/E: (0, 3)
#   Am/G: (0, 3)
#   A: (5, 4)
#   Am: (7, 0)
#   G: (18, 20)
#   G/3C: (1, 0)
#   A7/C: (0, 3)
#   G/5: (3, 0)
#   Em/b7: (4, 0)
# Acordes com Contagem Igual (%): 4.35
# Posições dos Acordes:
#   posicoes_corretas: 19
#   posicoes_incorretas: 300
# Posições Iguais dos Acordes (%): 5.96
# Sequências:
#   sequências: [['G', 'D/3', 'Em'], ['C', 'D', 'G', 'D/3', 'Em'], ['A', 'C', 'G/B'], ['C', 'G/B'], ['Am', 'D'], ['D'], ['C', 'D', 'G'], ['G/B', 'C', 'D', 'G', 'C', 'D', 'G', 'D/3', 'Em'], ['G/5', 'C', 'G/B'], ['G/B'], ['D', 'G'], ['G/5', 'C'], ['D', 'G', 'C', 'D7', 'G', 'D/3', 'Em'], ['Am7', 'D7', 'G', 'D/3', 'Em'], ['C', 'D', 'G'], ['D/3'], ['D', 'Em'], ['C', 'D', 'G', 'D/3', 'Em'], ['A'], ['A']]
#   substituições: [{'cifra gerada': ['Em/b7'], 'cifra validacao': ['Em/D']}, {'cifra gerada': ['Em/b7'], 'cifra validacao': ['Em/D']}, {'cifra gerada': ['G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B'], 'cifra validacao': ['Am7', 'Am/G']}, {'cifra gerada': ['D/3', 'Em', 'G/5', 'C', 'A', 'D', 'G', 'D/3', 'Em', 'A', 'D', 'A/3', 'C', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'C', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'Am', 'D', 'G', 'G', 'Am', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B'], 'cifra validacao': ['F/A']}, {'cifra gerada': ['G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'Am'], 'cifra validacao': ['D', 'C/E']}, {'cifra gerada': ['D/3', 'Em'], 'cifra validacao': ['F/A']}, {'cifra gerada': ['G/5CG'], 'cifra validacao': ['Em/D', 'C', 'G/B']}, {'cifra gerada': ['Em/b7'], 'cifra validacao': ['Em/D', 'G', 'C', 'G/B', 'G', 'Am7', 'D', 'G', 'C', 'G/B', 'C', 'G/B', 'Am7', 'Am/G', 'Am/E', 'D']}, {'cifra gerada': ['Em/b7'], 'cifra validacao': ['Em/D']}, {'cifra gerada': ['D', 'C'], 'cifra validacao': ['Em', 'Em/D', 'A7/C']}]
#   exclusões: [['G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B'], ['G', 'Am', 'G/3C'], ['G'], ['G', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'Am', 'D', 'G', 'D/3', 'Em', 'A/3A', 'C', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'C', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'G/B', 'Am']]
#   inserções: [['Em/D', 'C', 'D', 'A', 'G', 'D/F', 'A', 'Em', 'Em/D', 'A7/C', 'C'], ['Am7', 'Am/G', 'Am/E'], ['F/A', 'G/B', 'C'], ['G', 'G'], ['Em/D', 'C', 'D', 'G', 'D/F', 'Em', 'Em/D', 'C', 'D'], ['G', 'D/F']]
#   porcentagem_iguais: 50.0
#   porcentagem_diferentes: 50.0
# Sequências Iguais (%): 50.0
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'LOVE ME TENDER' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 21.52
# Acordes em Comum: {'Bm', 'E7', 'A7', 'A', 'B7', 'F', 'G', 'D', 'F#'}
# Acordes em Comum (%): 45.0
# Só na Cifra Gerada: {'E', 'F#7', 'Am', 'F#/5'}
# Só na Cifra Gerada (%): 20.0
# Só na Cifra de Validação: {'E/G', 'A7/E', 'D7', 'D/A', 'E7/B', 'A/C', 'Gm6'}
# Só na Cifra de Validação (%): 35.0
# Acordes com Contagem:
#   A7/E: (0, 3)
#   D7: (0, 3)
#   F: (4, 4)
#   D: (15, 24)
#   E: (4, 0)
#   F#: (2, 3)
#   F#7: (1, 0)
#   E/G: (0, 7)
#   Bm: (3, 3)
#   Gm6: (0, 3)
#   E7: (6, 9)
#   A7: (4, 9)
#   D/A: (0, 6)
#   E7/B: (0, 2)
#   A: (15, 8)
#   Am: (1, 0)
#   B7: (3, 3)
#   F#/5: (1, 0)
#   G: (3, 3)
#   A/C: (0, 6)
# Acordes com Contagem Igual (%): 20.0
# Posições dos Acordes:
#   posicoes_corretas: 6
#   posicoes_incorretas: 137
# Posições Iguais dos Acordes (%): 4.2
# Sequências:
#   sequências: [['D'], ['D', 'E', 'E7', 'A'], ['A7', 'D'], ['E7', 'A7'], ['A', 'D'], ['A7', 'D', 'F#', 'Bm', 'D', 'G'], ['D', 'A'], ['B7'], ['E7', 'F', 'A']]
#   substituições: [{'cifra gerada': ['A'], 'cifra validacao': ['D', 'D/A', 'E7']}]
#   exclusões: [['A', 'E', 'A', 'D', 'A'], ['D', 'A', 'F#', 'Bm', 'Am', 'G', 'D', 'A', 'B7', 'E7', 'F'], ['D', 'E', 'F'], ['A', 'F#/5', 'F#7', 'Bm', 'D', 'G', 'D', 'A', 'B7', 'E7', 'F', 'A7', 'D', 'A', 'A', 'E7', 'A', 'D', 'E']]
#   inserções: [['Gm6'], ['D'], ['E7'], ['A/C', 'D', 'A', 'D', 'D/A', 'E7', 'E/G', 'A7', 'A/C', 'D', 'D', 'D/A', 'E7', 'E/G', 'F', 'A7', 'A7/E', 'D', 'A', 'D', 'F#', 'Bm', 'D7', 'G', 'Gm6', 'D', 'A', 'D', 'B7', 'E7', 'E/G', 'F', 'A7', 'A/C', 'D', 'A', 'D', 'D/A', 'E7', 'E7/B', 'A7', 'A7/E', 'D', 'D', 'D/A', 'E7', 'E7/B', 'A7', 'A7/E', 'D', 'D', 'F#', 'Bm', 'D7', 'G', 'Gm6', 'D', 'A', 'D', 'B7', 'E7', 'E/G', 'F', 'A7', 'A/C', 'D', 'A']]
#   porcentagem_iguais: 50.0
#   porcentagem_diferentes: 50.0
# Sequências Iguais (%): 50.0
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'MY SACRIFICE' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 8.06
# Acordes em Comum: {'F', 'Ab', 'D'}
# Acordes em Comum (%): 18.75
# Só na Cifra Gerada: {'Bm', 'C', 'A/3', 'A/3D', 'A', 'G', 'G/b7', 'G/5'}
# Só na Cifra Gerada (%): 50.0
# Só na Cifra de Validação: {'G5', 'A11/C', 'D5', 'Bm7', 'D/C'}
# Só na Cifra de Validação (%): 31.25
# Acordes com Contagem:
#   G5: (0, 12)
#   A/3: (7, 0)
#   F: (3, 1)
#   D: (20, 8)
#   D5: (0, 12)
#   G/b7: (1, 0)
#   Bm: (13, 0)
#   Ab: (4, 4)
#   C: (2, 0)
#   A/3D: (1, 0)
#   A: (1, 0)
#   G: (14, 0)
#   A11/C: (0, 5)
#   G/5: (1, 0)
#   Bm7: (0, 12)
#   D/C: (0, 3)
# Acordes com Contagem Igual (%): 6.25
# Posições dos Acordes:
#   posicoes_corretas: 2
#   posicoes_incorretas: 161
# Posições Iguais dos Acordes (%): 1.23
# Sequências:
#   sequências: [['D', 'Bm', 'G', 'F', 'D', 'Bm', 'G', 'D', 'A/3', 'Bm', 'G', 'D', 'A/3', 'Ab'], ['Bm', 'G', 'D', 'Bm', 'G', 'D', 'Bm', 'G', 'D'], ['A/3'], ['D'], ['Bm', 'G', 'D', 'A/3'], ['Bm', 'G', 'D'], ['D'], ['Bm', 'G', 'D'], ['D'], ['D'], ['D']]
#   substituições: [{'cifra gerada': ['A/3D'], 'cifra validacao': ['Ab']}]
#   exclusões: [['G'], ['D', 'Bm', 'G', 'G/b7', 'D'], ['C'], ['Ab', 'D'], ['G/5'], ['A/3', 'Ab'], ['Bm', 'G'], ['C', 'A/3'], ['Bm', 'G', 'F', 'D', 'A/3', 'A', 'Ab', 'Bm', 'G', 'F', 'D']]
#   inserções: [['Bm7', 'G5'], ['D/C', 'Ab', 'Bm7', 'G5', 'D5', 'D5', 'D5', 'D5', 'D', 'A11/C', 'Bm7', 'G5', 'D', 'D/C', 'Ab']]
#   porcentagem_iguais: 47.83
#   porcentagem_diferentes: 52.17
# Sequências Iguais (%): 47.83
# -------------------------------------------------------------
#
#
# ------------EVALUATING 'WHEREVER YOU WILL GO FOTOS' CHORD SHEET----------------
#
# Diferença de Quantidade Gerada (%): 18.01
# Acordes em Comum: {'C', 'G4/B', 'Dm', 'Am', 'F', 'G', 'B'}
# Acordes em Comum (%): 63.64
# Só na Cifra Gerada: {'F/5'}
# Só na Cifra Gerada (%): 9.09
# Só na Cifra de Validação: {'F7', 'Am7', 'A'}
# Só na Cifra de Validação (%): 27.27
# Acordes com Contagem:
#   F/5: (1, 0)
#   C: (23, 17)
#   F7: (0, 13)
#   G4/B: (24, 12)
#   Dm: (2, 1)
#   Am: (12, 1)
#   A: (0, 1)
#   F: (17, 4)
#   G: (15, 3)
#   Am7: (0, 13)
#   B: (1, 1)
# Acordes com Contagem Igual (%): 9.09
# Posições dos Acordes:
#   posicoes_corretas: 6
#   posicoes_incorretas: 158
# Posições Iguais dos Acordes (%): 3.66
# Sequências:
#   sequências: [['C', 'G'], ['F', 'C', 'G', 'Am'], ['C'], ['F', 'C', 'G', 'Am', 'F', 'C', 'G', 'Am', 'F', 'C', 'G4/B'], ['F', 'Am', 'B'], ['F', 'F'], ['C', 'G', 'Am', 'F', 'C', 'G', 'Dm', 'F', 'C', 'G'], ['C', 'G', 'Am', 'F', 'C', 'G', 'Am', 'F', 'C', 'G', 'Am', 'F', 'C', 'G', 'Am', 'F'], ['Am']]
#   substituições: [{'cifra gerada': ['C', 'F', 'C', 'G', 'C', 'F/5', 'C', 'G', 'C'], 'cifra validacao': ['Am7']}]
#   exclusões: [['G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'Am', 'C', 'F', 'C', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B', 'G4/B'], ['C'], ['Am', 'F', 'C', 'G', 'G', 'Dm', 'F'], ['C']]
#   inserções: [['F7'], ['G4/B', 'Am7', 'F7', 'A', 'C', 'G4/B', 'Am7', 'F7', 'C', 'C', 'G4/B', 'Am7'], ['C'], ['F7']]
#   porcentagem_iguais: 50.0
#   porcentagem_diferentes: 50.0
# Sequências Iguais (%): 50.0
# -------------------------------------------------------------

# %%
calculate_general_averages(comparisons)
print("\n\n")
analyze_exclusive_chords(comparisons)
print("\n\n")
analyze_sequence_differences(comparisons)
# Out:
# +------------------------------------+-------------+------------------------+
# |               Metric               | Average (%) | Standard Deviation (%) |
# +------------------------------------+-------------+------------------------+
# | Diferença de Quantidade Gerada (%) |    15.53    |         13.25          |
# |        Acordes em Comum (%)        |    46.63    |         19.66          |
# |       Só na Cifra Gerada (%)       |    30.14    |         12.05          |
# |    Só na Cifra de Validação (%)    |    23.22    |         16.26          |
# |   Acordes com Contagem Igual (%)   |    11.63    |         12.39          |
# |  Posições Iguais dos Acordes (%)   |    2.56     |          2.13          |
# |       Sequências Iguais (%)        |    48.6     |          1.15          |
# +------------------------------------+-------------+------------------------+
#
#
#
# Acordes Mais Frequentes (Só Geradas):
#  +------------------------+-----------+
# | Chord (Generated Only) | Frequency |
# +------------------------+-----------+
# |           G            |     4     |
# |           Am           |     4     |
# |           E            |     3     |
# |           F            |     3     |
# |           Bb           |     3     |
# |           Cm           |     3     |
# |           Eb           |     3     |
# |           D            |     3     |
# |           D7           |     3     |
# |          E/3           |     3     |
# +------------------------+-----------+
# Acordes Mais Frequentes (Só Validação):
#  +-------------------------+-----------+
# | Chord (Validation Only) | Frequency |
# +-------------------------+-----------+
# |           E/G           |     4     |
# |           A7            |     3     |
# |           A/C           |     3     |
# |           F#            |     3     |
# |          A7/C           |     3     |
# |           E4            |     2     |
# |           E6            |     2     |
# |           G#            |     2     |
# |          Em/D           |     2     |
# |           B7            |     2     |
# +-------------------------+-----------+
#
#
#
# +------------------------------------+-----------+
# |               Metric               |   Value   |
# +------------------------------------+-----------+
# |   Média de Sequências Iguais (%)   |   48.6    |
# | Média de Sequências Diferentes (%) |   51.4    |
# |       Total de Substituições       |    66     |
# |         Total de Exclusões         |    95     |
# |         Total de Inserções         |    88     |
# |       Tipo de Erro Dominante       | Exclusões |
# +------------------------------------+-----------+
